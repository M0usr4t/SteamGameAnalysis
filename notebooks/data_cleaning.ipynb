# %%
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import os
import numpy as np
import math
import re

# %% [markdown]
# Steam works API data

# %%
data = pq.read_table('../data/steam_app_details.parquet')
steamworks_df = pa.Table.to_pandas(data)
steamworks_df.head()
# Out:
#   appid                       name          developers publishers  \
# 0    10             Counter-Strike             [Valve]    [Valve]
# 1    20      Team Fortress Classic             [Valve]    [Valve]
# 2    30              Day of Defeat             [Valve]    [Valve]
# 3    40         Deathmatch Classic             [Valve]    [Valve]
# 4    50  Half-Life: Opposing Force  [Gearbox Software]    [Valve]
#
#    initial_price  final_price                                      platforms  \
# 0          999.0        999.0  {'linux': True, 'mac': True, 'windows': True}
# 1          499.0        499.0  {'linux': True, 'mac': True, 'windows': True}
# 2          499.0        499.0  {'linux': True, 'mac': True, 'windows': True}
# 3          499.0        499.0  {'linux': True, 'mac': True, 'windows': True}
# 4          499.0        499.0  {'linux': True, 'mac': True, 'windows': True}
#
#    metacritic                                  genres release_date
# 0        88.0  [{'description': 'Action', 'id': '1'}]  Nov 1, 2000
# 1         NaN  [{'description': 'Action', 'id': '1'}]  Apr 1, 1999
# 2        79.0  [{'description': 'Action', 'id': '1'}]  May 1, 2003
# 3         NaN  [{'description': 'Action', 'id': '1'}]  Jun 1, 2001
# 4         NaN  [{'description': 'Action', 'id': '1'}]  Nov 1, 1999

# %%
steamworks_df['appid'] = steamworks_df['appid'].astype(int)

# %%
steamworks_df.dtypes
# Out:
# appid              int64
# name              object
# developers        object
# publishers        object
# initial_price    float64
# final_price      float64
# platforms         object
# metacritic       float64
# genres            object
# release_date      object
# dtype: object

# %%
len(steamworks_df)
# Out:
# 18096

# %% [markdown]
# Cleaning problematic names/developers/publishers/genres

# %%
print(type(steamworks_df['developers'].iloc[0]))
print(type(steamworks_df['publishers'].iloc[0]))
print(type(steamworks_df['genres'].iloc[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
steamworks_df['developers'] = steamworks_df['developers'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)
steamworks_df['publishers'] = steamworks_df['publishers'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)
steamworks_df['genres'] = steamworks_df['genres'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)

# %%
steamworks_df['name'] = steamworks_df['name'].str.title()
steamworks_df['publishers'] = steamworks_df['publishers'].apply(lambda pubs: [pub.title() for pub in pubs] if isinstance(pubs, list) else pubs)
steamworks_df['developers'] = steamworks_df['developers'].apply(lambda devs: [dev.title() for dev in devs] if isinstance(devs, list) else devs)

# %%
def is_ascii(s):
    return bool(re.match(r'^[\x00-\x7F]*$', s))

# %%
steamworks_df = steamworks_df[steamworks_df['name'].apply(is_ascii)]
steamworks_df = steamworks_df[steamworks_df['developers'].apply(lambda devs: devs != [] and all(is_ascii(dev) for dev in devs))]
steamworks_df = steamworks_df[steamworks_df['publishers'].apply(lambda pubs: pubs != [] and all(is_ascii(pub) for pub in pubs))]

# %%
steamworks_df = steamworks_df[~steamworks_df['publishers'].apply(lambda pubs: 'N/A' in pubs)]

# %% [markdown]
# normalizing genres

# %%
print(set([genre['description'] for genres in steamworks_df['genres'] for genre in genres]))
# Out:
# {'Game Development', 'Design & Illustration', 'Utilities', 'Indie', 'Animation & Modeling', 'Accesso anticipato', 'Бойовики', 'Violent', 'Strategy', 'Racing', 'Симулятори', 'Simulazione', 'Simulation', 'Casual', 'Adventure', 'Sports', 'RPG', 'Рольові ігри', 'Action', 'Early Access', 'Пригоди', 'Massively Multiplayer', 'Free To Play', 'Education'}

# %%
genre_translation = {
    'Бойовики': 'Action',
    'Пригоди': 'Adventure',
    'Рольові ігри': 'RPG',
    'Симулятори': 'Simulation',
    'Simulazione': 'Simulation',
    'Accesso anticipato': 'Early Access'
}

for index, row in steamworks_df.iterrows():
    for genre in row['genres']:
        if genre['description'] in genre_translation:
            genre['description'] = genre_translation[genre['description']]
print(set([genre['description'] for genres in steamworks_df['genres'] for genre in genres]))
# Out:
# {'Game Development', 'Design & Illustration', 'Massively Multiplayer', 'Strategy', 'Free To Play', 'Racing', 'Adventure', 'Violent', 'Education', 'Utilities', 'Sports', 'Indie', 'RPG', 'Animation & Modeling', 'Simulation', 'Action', 'Early Access', 'Casual'}

# %%
target_genres = ['Animation & Modeling', 'Design & Illustration', 'Utilities', 'Game Development', 'Violent', 'Education']
matching_rows = steamworks_df[
    steamworks_df['genres'].apply(lambda genre_list: any(genre['description'] in target_genres for genre in genre_list))
]

# %%
matching_rows
# Out:
#          appid                     name  \
# 1153    711570  Epic Battle Simulator 2
# 7399   2308700                 Gb Basic
# 9750   2645040                    Cargo
# 10376  2721170              Brutal Ball
# 16797  3267430             Last Remains
#
#                                    developers                    publishers  \
# 1153                         [Rappid Studios]              [Rappid Studios]
# 7399                              [Tony Wang]                   [Tony Wang]
# 9750               [Scythe, Killswitch Games]    [Killswitch Entertainment]
# 10376            [Lucid Matrix Studios, Inc.]  [Lucid Matrix Studios, Inc.]
# 16797  [Earn Alliance, Renderer Game Studios]               [Earn Alliance]
#
#        initial_price  final_price  \
# 1153           499.0        499.0
# 7399             NaN          NaN
# 9750             NaN          NaN
# 10376            NaN          NaN
# 16797            NaN          NaN
#
#                                              platforms  metacritic  \
# 1153   {'linux': False, 'mac': False, 'windows': True}         NaN
# 7399    {'linux': True, 'mac': False, 'windows': True}         NaN
# 9750   {'linux': False, 'mac': False, 'windows': True}         NaN
# 10376  {'linux': False, 'mac': False, 'windows': True}         NaN
# 16797  {'linux': False, 'mac': False, 'windows': True}         NaN
#
#                                                   genres     release_date
# 1153   [{'description': 'Violent', 'id': '73'}, {'des...      Nov 2, 2017
# 7399   [{'description': 'Indie', 'id': '23'}, {'descr...  To be announced
# 9750   [{'description': 'Indie', 'id': '23'}, {'descr...      Coming soon
# 10376  [{'description': 'Action', 'id': '1'}, {'descr...      Apr 4, 2024
# 16797  [{'description': 'Action', 'id': '1'}, {'descr...     January 2025

# %%
steamworks_df['genres'] = steamworks_df['genres'].apply(
        lambda genre_list: [genre for genre in genre_list if genre['description'] not in target_genres])

# %%
print(set([genre['description'] for genres in steamworks_df['genres'] for genre in genres]))
# Out:
# {'Massively Multiplayer', 'Strategy', 'Free To Play', 'Racing', 'Adventure', 'Sports', 'Indie', 'RPG', 'Simulation', 'Action', 'Early Access', 'Casual'}

# %%
steamworks_df = steamworks_df[(steamworks_df['developers'].apply(lambda x: x != [])) &
                              (steamworks_df['publishers'].apply(lambda x: x != []))]

# %%
def strip_list_values(lst):
    return [item.strip() for item in lst if isinstance(item, str)]

steamworks_df['developers'] = steamworks_df['developers'].apply(strip_list_values)
steamworks_df['publishers'] = steamworks_df['publishers'].apply(strip_list_values)

# %% [markdown]
# Handling nulls

# %%
print(f"name (NULLS): {(steamworks_df['name'] == "Unknown").sum()}")
print(f"name (EMPTY): {(steamworks_df['name'] == "").sum()}")
print(f"developers (NULLS): {(steamworks_df['developers'].apply(lambda x: x == [])).sum()}")
print(f"publishers (NULLS): {steamworks_df['publishers'].apply(lambda x: x == []).sum()}")
print(f"initial_price (NULLS): {steamworks_df['initial_price'].isnull().sum()}")
print(f"final_price (NULLS): {steamworks_df['final_price'].isnull().sum()}")
print(f"platforms (NULLS): {steamworks_df['platforms'].apply(lambda x: x == {'linux': False, 'mac': False, 'windows': False}).sum()}")
print(f"metacritic (NULLS): {steamworks_df['metacritic'].isnull().sum()}")
print(f"genres (NULLS): {steamworks_df['genres'].apply(lambda x: x == []).sum()}")
print(f"release_date (NULLS): {(steamworks_df['release_date'] == "Unknown").sum()}")
# Out:
# name (NULLS): 0
# name (EMPTY): 1
# developers (NULLS): 0
# publishers (NULLS): 0
# initial_price (NULLS): 8882
# final_price (NULLS): 8882
# platforms (NULLS): 0
# metacritic (NULLS): 15913
# genres (NULLS): 25
# release_date (NULLS): 0

# %%
app_id_to_drop = steamworks_df.loc[steamworks_df['name'] == '', 'appid']
print(app_id_to_drop.tolist())
# Out:
# [2942140]

# %%
steamworks_df = steamworks_df[~steamworks_df['appid'].isin(app_id_to_drop)]

# %%
null_genres = steamworks_df.loc[steamworks_df['genres'].apply(lambda x: len(x) == 0)]
print(null_genres)
# Out:
#         appid                           name             developers  \
# 1730   955900  Amazing Cultivation Simulator            [Gsq Games]
# 2363  1155330                    Showgunners            [Artificer]
# 2673  1247100          Spellmaster: The Saga  [Spellbook Creations]
# 2705  1256690               Hot And Lovely 2         [Lovely Games]
# 2863  1290070               Hot And Lovely 3         [Lovely Games]
# 3071  1347430                     Cute Honey         [Lovely Games]
# 3270  1399370                   Cute Honey 2         [Lovely Games]
# 4154  1605010                 Adorable Witch         [Lovely Games]
# 4548  1709460               Hot And Lovely 4         [Lovely Games]
# 4549  1709500               Adorable Witch 2         [Lovely Games]
# 4691  1740000         Cute Honey: Bunny Girl         [Lovely Games]
# 5218  1864070         Yume : Special Edition         [Lovely Games]
# 5310  1883530                    Snackhunter       [Polypirates Ug]
# 5376  1901340                    Ero Manager         [Lovely Games]
# 5432  1913490               Adorable Witch 3         [Lovely Games]
# 6102  2078120               Hot And Lovely 5         [Lovely Games]
# 6194  2095290               Theseus Protocol      [Yuetang(Xiamen)]
# 7152  2271980    Adorable Witch5 : Lingering          [Lovelygames]
# 7154  2272050   Fairy Biography3 : Obsession          [Lovelygames]
# 7282  2292160                       Remorses    [Twistedline Games]
# 7595  2340510                   Moon'S Creed        [Creedon Games]
# 7731  2360410                     Domenation     [Blackmouth Games]
# 8459  2464120                         Yume 3         [Lovely Games]
# 8533  2475460                       Sos Ops!              [Artdock]
# 8793  2511030                    Deep Secret         [Lovely Games]
#
#                                     publishers  initial_price  final_price  \
# 1730                               [Gsq Games]         2499.0       2499.0
# 2363             [Good Shepherd Entertainment]         2999.0       2999.0
# 2673                     [Valkyrie Initiative]         2499.0       2499.0
# 2705  [Lovely Games Hentai Club, Lovely Games]          199.0        149.0
# 2863                [Lovely Games Hentai Club]          199.0        149.0
# 3071  [Lovely Games Hentai Club, Lovely Games]          199.0        199.0
# 3270  [Lovely Games Hentai Club, Lovely Games]          199.0        199.0
# 4154                            [Lovely Games]          199.0        199.0
# 4548                            [Lovely Games]          199.0        199.0
# 4549                            [Lovely Games]          199.0        199.0
# 4691                            [Lovely Games]          499.0        499.0
# 5218                            [Lovely Games]          399.0        399.0
# 5310                        [Cobratekku Games]          999.0        999.0
# 5376                            [Lovely Games]          199.0        199.0
# 5432                            [Lovely Games]          299.0        299.0
# 6102  [Lovely Games Hentai Club, Lovely Games]          199.0        159.0
# 6194                           [Archive Games]          999.0        999.0
# 7152                             [Lovelygames]          899.0        899.0
# 7154                             [Lovelygames]          699.0        699.0
# 7282                       [Twistedline Games]            NaN          NaN
# 7595                           [Creedon Games]            NaN          NaN
# 7731                        [Blackmouth Games]            NaN          NaN
# 8459                            [Lovely Games]          499.0        499.0
# 8533                                 [Artdock]          599.0        599.0
# 8793                            [Lovely Games]          399.0        319.0
#
#                                             platforms  metacritic genres  \
# 1730  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 2363  {'linux': False, 'mac': False, 'windows': True}        75.0     []
# 2673  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 2705  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 2863  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 3071  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 3270  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 4154  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 4548  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 4549  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 4691  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 5218  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 5310   {'linux': False, 'mac': True, 'windows': True}         NaN     []
# 5376  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 5432  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 6102  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 6194  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 7152  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 7154  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 7282    {'linux': True, 'mac': True, 'windows': True}         NaN     []
# 7595  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 7731  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 8459  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 8533  {'linux': False, 'mac': False, 'windows': True}         NaN     []
# 8793  {'linux': False, 'mac': False, 'windows': True}         NaN     []
#
#       release_date
# 1730  Nov 24, 2020
# 2363   May 2, 2023
# 2673  Feb 16, 2022
# 2705  Mar 26, 2020
# 2863  May 24, 2020
# 3071  Jul 22, 2020
# 3270  Sep 30, 2020
# 4154  Jun 16, 2021
# 4548  Sep 15, 2021
# 4549  Oct 21, 2021
# 4691  Nov 25, 2021
# 5218  Mar 25, 2022
# 5310   Jul 8, 2022
# 5376  Mar 11, 2022
# 5432   May 7, 2022
# 6102   Aug 5, 2022
# 6194  Aug 22, 2023
# 7152  May 19, 2023
# 7154  Mar 24, 2023
# 7282          2025
# 7595  Dec 13, 2024
# 7731   Jul 4, 2024
# 8459  Aug 25, 2023
# 8533  Nov 30, 2023
# 8793  Oct 20, 2023

# %%
steamworks_df = steamworks_df.drop(null_genres.index)

# %%
print(steamworks_df['developers'][0])
print(steamworks_df['publishers'][0])
print(steamworks_df['platforms'][0])
print(steamworks_df['name'][0])
print(steamworks_df['initial_price'][0])
print(steamworks_df['final_price'][0])
print(steamworks_df['metacritic'][0])
print(steamworks_df['release_date'][0])
print(steamworks_df['genres'][0])
# Out:
# ['Valve']
# ['Valve']
# {'linux': True, 'mac': True, 'windows': True}
# Counter-Strike
# 999.0
# 999.0
# 88.0
# Nov 1, 2000
# [{'description': 'Action', 'id': '1'}]

# %% [markdown]
# Splitting dataframe

# %%
names = []
developers = []
publishers = []
game_prices = {}
genres = []
platforms = []
metacritic_scores = []
release_dates = []

for index, row in steamworks_df.iterrows():
    game_id = row['appid']
    
    names.append({'game_id': game_id, 'name': str(row['name'])})
    release_dates.append({'game_id': game_id, 'release_date': str(row['release_date'])})
    
    for developer in row['developers']:
        if developer:
            developers.append({'game_id': game_id, 'developer': str(developer)})
    
    for publisher in row['publishers']:
        if publisher:
            publishers.append({'game_id': game_id, 'publisher': str(publisher)})
    
    if row['platforms'].get('linux', False):
        platforms.append({'game_id': game_id, 'platform': 'linux'})
    if row['platforms'].get('mac', False):
        platforms.append({'game_id': game_id, 'platform': 'mac'})
    if row['platforms'].get('windows', False):
        platforms.append({'game_id': game_id, 'platform': 'windows'})
    
    for genre in row['genres']:
        genres.append({'game_id': game_id, 'genre': str(genre['description'])})

    game_prices[game_id] = {'initial_price': float(row['initial_price']), 'current_price': float(row['final_price'])}

    if not math.isnan(row['metacritic']):
        metacritic_scores.append({'game_id': game_id, 'score': float(row['metacritic'])})

# %% [markdown]
# Steam Spy API Data

# %%
game_ids = steamworks_df['appid']

# %%
data = pq.read_table('../data/steam_spy_details.parquet')
steamspy_df = pa.Table.to_pandas(data)
steamspy_df = steamspy_df[steamspy_df['appid'].isin(game_ids)]
steamspy_df.head()
# Out:
#    appid score_rank  positive  negative  userscore                    owners  \
# 0     10               236255      6239          0  10,000,000 .. 20,000,000
# 1     20                 7330      1093          0   5,000,000 .. 10,000,000
# 2     30                 6267       672          0      500,000 .. 1,000,000
# 3     40                 2553       527          0   5,000,000 .. 10,000,000
# 4     50                22337      1116          0    2,000,000 .. 5,000,000
#
#    average_playtime  average_playtime_2weeks  median_playtime  \
# 0                 0                        0                0
# 1                 0                        0                0
# 2                 0                        0                0
# 3                 0                        0                0
# 4                 0                        0                0
#
#    median_playtime_2weeks    ccu current_price initial_price
# 0                       0  14998           999           999
# 1                       0     62           499           499
# 2                       0     98           499           499
# 3                       0      4           499           499
# 4                       0    101           499           499

# %%
steamspy_df['appid'] = steamspy_df['appid'].astype(int)

# %%
steamspy_df = steamspy_df[~steamspy_df['appid'].isin(app_id_to_drop)]

# %% [markdown]
# datatypes

# %%
steamspy_df.dtypes
# Out:
# appid                       int64
# score_rank                 object
# positive                    int32
# negative                    int32
# userscore                   int32
# owners                     object
# average_playtime            int32
# average_playtime_2weeks     int32
# median_playtime             int32
# median_playtime_2weeks      int32
# ccu                         int32
# current_price              object
# initial_price              object
# dtype: object

# %% [markdown]
# Handling nulls

# %%
print(f'Rank: {steamspy_df['score_rank'].apply(lambda x:x == '' or x== None).sum()}')
print(f'Positive: {steamspy_df['positive'].apply(lambda x: x == 0 or x == None or math.isnan(x)).sum()}')
print(f'Negative: {steamspy_df['negative'].apply(lambda x: x == 0 or x == None or math.isnan(x)).sum()}')
print(f'User Score: {steamspy_df['userscore'].apply(lambda x:x == 0 or x == None).sum()}')
print(f'Owners: {steamspy_df['owners'].apply(lambda x: x == '' or x==None).sum()}')
print(f'Avg Playtime: {steamspy_df['average_playtime'].apply(lambda x:x == 0 or x==None).sum()}')
print(f'Avg Playtime 2weeks: {steamspy_df['average_playtime_2weeks'].apply(lambda x:x == 0 or x==None).sum()}')
print(f'Median Playtime: {steamspy_df['median_playtime'].apply(lambda x:x == 0 or x==None).sum()}')
print(f'Median Playtime 2weeks: {steamspy_df['median_playtime_2weeks'].apply(lambda x:x == 0 or x==None).sum()}')
print(f'CCU: {steamspy_df['ccu'].apply(lambda x: x==None or math.isnan(x)).sum()}')
print(f'Current Price: {steamspy_df['current_price'].apply(lambda x: x==None or x=='').sum()}')
print(f'Initial Price: {steamspy_df['initial_price'].apply(lambda x: x==None or x=='').sum()}')
# Out:
# Rank: 16529
# Positive: 9830
# Negative: 10860
# User Score: 16529
# Owners: 0
# Avg Playtime: 16534
# Avg Playtime 2weeks: 16534
# Median Playtime: 16534
# Median Playtime 2weeks: 16534
# CCU: 0
# Current Price: 8506
# Initial Price: 8506

# %% [markdown]
# Dropping empty columns

# %%
steamspy_df.drop('score_rank', axis=1, inplace=True)
steamspy_df.drop('userscore', axis=1, inplace=True)
steamspy_df.drop('average_playtime', axis=1, inplace=True)
steamspy_df.drop('average_playtime_2weeks', axis=1, inplace=True)
steamspy_df.drop('median_playtime', axis=1, inplace=True)
steamspy_df.drop('median_playtime_2weeks', axis=1, inplace=True)

# %%
steamspy_df.head()
# Out:
#    appid  positive  negative                    owners    ccu current_price  \
# 0     10    236255      6239  10,000,000 .. 20,000,000  14998           999
# 1     20      7330      1093   5,000,000 .. 10,000,000     62           499
# 2     30      6267       672      500,000 .. 1,000,000     98           499
# 3     40      2553       527   5,000,000 .. 10,000,000      4           499
# 4     50     22337      1116    2,000,000 .. 5,000,000    101           499
#
#   initial_price
# 0           999
# 1           499
# 2           499
# 3           499
# 4           499

# %% [markdown]
# Compare and combine prices

# %%
steamworks_df.sort_values(by=['final_price'], ascending= False).head(25)
# Out:
#          appid                                               name  \
# 547     422610                                    1775: Rebellion
# 610     449460                   Commands & Colors: The Great War
# 4282   1643320               S.T.A.L.K.E.R. 2: Heart Of Chornobyl
# 7328   2300320                               Farming Simulator 25
# 186     244850                                    Space Engineers
# 4206   1620720                                 The Forest Quartet
# 11239  2829060                                      Computer Fury
# 99      105600                                           Terraria
# 101     107410                                             Arma 3
# 4588   1716310                              Awaken - Astral Blade
# 16128  3230890                   Hidden Space Station Top-Down 3D
# 12074  2914930                                             Rehash
# 15858  3214810                             Archaeology - Medieval
# 15857  3214800                            3D Puzzle - Gas Station
# 2860   1289890                                     Vr Long March
# 16126  3230870                          Archaeology - Frozen Wall
# 4601    292030                           The Witcher 3: Wild Hunt
# 16359  3244700                                Archaeology - Egypt
# 16360  3244710                      Archaeology - Post-Apocalypse
# 2879   1293180                   Suchart: Genius Artist Simulator
# 8293   2440510                                   Forza Motorsport
# 875     594650                                Hunt: Showdown 1896
# 2886   1293830                                    Forza Horizon 4
# 5902   2014780                                         X-Plane 12
# 7599   2340720  The Heroic Legend Of America: Second Revolutio...
#
#                   developers  \
# 547           [Hexwar Games]
# 610           [Hexwar Games]
# 4282        [Gsc Game World]
# 7328       [Giants Software]
# 186    [Keen Software House]
# 4206        [Mads & Friends]
# 11239  [Saj Game Electronic]
# 99                [Re-Logic]
# 101    [Bohemia Interactive]
# 4588     [Dark Pigeon Games]
# 16128       [Top-Down Games]
# 12074      [Reharmony Games]
# 15858     [Archaeologygames]
# 15857         [Puzzle Games]
# 2860                    [Rk]
# 16126     [Archaeologygames]
# 4601        [Cd Projekt Red]
# 16359     [Archaeologygames]
# 16360     [Archaeologygames]
# 2879          [Goose Minded]
# 8293               [Turn 10]
# 875                 [Crytek]
# 2886      [Playground Games]
# 5902      [Laminar Research]
# 7599         [Heroic Legend]
#
#                                               publishers  initial_price  \
# 547                                   [Hunted Cow Games]       248000.0
# 610                                   [Hunted Cow Games]       198000.0
# 4282   [Gsc Game World (Worldwide), Sega (Japan), 4Di...       139900.0
# 7328                                   [Giants Software]        99900.0
# 186                                [Keen Software House]        83500.0
# 4206                             [Bedtime Digital Games]        48000.0
# 11239                              [Saj Game Electronic]        40000.0
# 99                                            [Re-Logic]        38500.0
# 101                                [Bohemia Interactive]       189000.0
# 4588                                   [Esdigital Games]        22799.0
# 16128                                             [Hede]        19999.0
# 12074                                  [Reharmony Games]        19999.0
# 15858                                 [Archaeologygames]        19999.0
# 15857                                             [Hede]        19999.0
# 2860                                                [Rk]        19999.0
# 16126                                 [Archaeologygames]        19999.0
# 4601                                    [Cd Projekt Red]        14900.0
# 16359                                 [Archaeologygames]        19999.0
# 16360                                 [Archaeologygames]        19999.0
# 2879                                 [Hypetrain Digital]         9200.0
# 8293                                 [Xbox Game Studios]         8999.0
# 875                                             [Crytek]         8300.0
# 2886                                 [Xbox Game Studios]         7999.0
# 5902                                  [Laminar Research]         7999.0
# 7599                                     [Heroic Legend]         7999.0
#
#        final_price                                        platforms  \
# 547       248000.0  {'linux': False, 'mac': False, 'windows': True}
# 610       198000.0  {'linux': False, 'mac': False, 'windows': True}
# 4282      139900.0  {'linux': False, 'mac': False, 'windows': True}
# 7328       99900.0   {'linux': False, 'mac': True, 'windows': True}
# 186        83500.0  {'linux': False, 'mac': False, 'windows': True}
# 4206       48000.0  {'linux': False, 'mac': False, 'windows': True}
# 11239      40000.0  {'linux': False, 'mac': False, 'windows': True}
# 99         38500.0    {'linux': True, 'mac': True, 'windows': True}
# 101        37800.0   {'linux': False, 'mac': True, 'windows': True}
# 4588       22799.0  {'linux': False, 'mac': False, 'windows': True}
# 16128      19999.0    {'linux': True, 'mac': True, 'windows': True}
# 12074      19999.0  {'linux': False, 'mac': False, 'windows': True}
# 15858      19999.0    {'linux': True, 'mac': True, 'windows': True}
# 15857      19999.0    {'linux': True, 'mac': True, 'windows': True}
# 2860       19999.0  {'linux': False, 'mac': False, 'windows': True}
# 16126      19999.0    {'linux': True, 'mac': True, 'windows': True}
# 4601       14900.0  {'linux': False, 'mac': False, 'windows': True}
# 16359      11999.0  {'linux': False, 'mac': False, 'windows': True}
# 16360      11999.0  {'linux': False, 'mac': False, 'windows': True}
# 2879        9200.0  {'linux': False, 'mac': False, 'windows': True}
# 8293        8999.0  {'linux': False, 'mac': False, 'windows': True}
# 875         8300.0  {'linux': False, 'mac': False, 'windows': True}
# 2886        7999.0  {'linux': False, 'mac': False, 'windows': True}
# 5902        7999.0    {'linux': True, 'mac': True, 'windows': True}
# 7599        7999.0  {'linux': False, 'mac': False, 'windows': True}
#
#        metacritic                                             genres  \
# 547           NaN           [{'description': 'Strategy', 'id': '2'}]
# 610           NaN           [{'description': 'Strategy', 'id': '2'}]
# 4282          NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 7328          NaN        [{'description': 'Simulation', 'id': '28'}]
# 186           NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 4206          NaN  [{'description': 'Adventure', 'id': '25'}, {'d...
# 11239         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 99           83.0  [{'description': 'Action', 'id': '1'}, {'descr...
# 101          74.0  [{'description': 'Action', 'id': '1'}, {'descr...
# 4588          NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 16128         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 12074         NaN  [{'description': 'Adventure', 'id': '25'}, {'d...
# 15858         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 15857         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 2860          NaN        [{'description': 'Simulation', 'id': '28'}]
# 16126         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 4601         93.0                [{'description': 'RPG', 'id': '3'}]
# 16359         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 16360         NaN  [{'description': 'Action', 'id': '1'}, {'descr...
# 2879          NaN  [{'description': 'Adventure', 'id': '25'}, {'d...
# 8293          NaN             [{'description': 'Racing', 'id': '9'}]
# 875          81.0             [{'description': 'Action', 'id': '1'}]
# 2886          NaN             [{'description': 'Racing', 'id': '9'}]
# 5902          NaN        [{'description': 'Simulation', 'id': '28'}]
# 7599          NaN  [{'description': 'Adventure', 'id': '25'}, {'d...
#
#           release_date
# 547       29 Sep, 2016
# 610       19 Jan, 2017
# 4282   20 листоп. 2024
# 7328   12 листоп. 2024
# 186        1 Mar, 2019
# 4206       8 Dec, 2022
# 11239     16 Mar, 2024
# 99        17 May, 2011
# 101       12 Sep, 2013
# 4588      22 Oct, 2024
# 16128     Oct 20, 2024
# 12074      Nov 7, 2024
# 15858     Oct 11, 2024
# 15857     Oct 20, 2024
# 2860       Nov 4, 2020
# 16126     Oct 13, 2024
# 4601      18 May, 2015
# 16359      Nov 2, 2024
# 16360      Nov 2, 2024
# 2879      13 Oct, 2022
# 8293       9 Oct, 2023
# 875       27 Aug, 2019
# 2886       9 Mar, 2021
# 5902      Dec 17, 2022
# 7599      Jun 18, 2023

# %%
steamspy_df['initial_price'] = steamspy_df['initial_price'].fillna(0).astype(float)
steamspy_df['current_price'] = steamspy_df['current_price'].fillna(0).astype(float)
steamspy_df['initial_price'] = steamspy_df['initial_price'].astype(float)
steamspy_df['current_price'] = steamspy_df['current_price'].astype(float)
steamspy_df.sort_values(by=['initial_price'], ascending= False).head(25)
# Out:
#          appid  positive  negative                  owners    ccu  \
# 2860   1289890         4         4             0 .. 20,000      0
# 12074  2914930         0         0             0 .. 20,000      0
# 16126  3230870         0         0             0 .. 20,000      0
# 16360  3244710         6         1             0 .. 20,000      0
# 16359  3244700         5         2             0 .. 20,000      0
# 5902   2014780      2872       604      100,000 .. 200,000    511
# 7599   2340720         4         5             0 .. 20,000      0
# 10054  2679460     14829      1485    500,000 .. 1,000,000  11776
# 8988   2537590         0         0             0 .. 20,000      0
# 8293   2440510      3521      4628  1,000,000 .. 2,000,000    518
# 6067   2072450     13016      1305      200,000 .. 500,000   1949
# 6434   2140330      3832      4555      100,000 .. 200,000   1253
# 11718  2878980      6045      4785      200,000 .. 500,000  18774
# 4883   1790600     45545      4533  2,000,000 .. 5,000,000  11395
# 7035   2246340         0         0             0 .. 20,000      0
# 13440  3043810         0         0             0 .. 20,000      0
# 10044  2677660         0         0             0 .. 20,000      0
# 10188  2698940      2530       967      100,000 .. 200,000    912
# 4833   1778820     28115     13965    500,000 .. 1,000,000   6011
# 2892   1295660         0         0             0 .. 20,000      0
# 3086   1351630      1524        88       50,000 .. 100,000     80
# 6665   2183900     93045     23445  2,000,000 .. 5,000,000  13395
# 7432   2315690      3778      1448      200,000 .. 500,000   1088
# 3036   1341200       854       889      100,000 .. 200,000     35
# 12984  3002850         0         0             0 .. 20,000      0
#
#        current_price  initial_price
# 2860         19999.0        19999.0
# 12074        19999.0        19999.0
# 16126        11999.0        19999.0
# 16360        11999.0        19999.0
# 16359        11999.0        19999.0
# 5902          7999.0         7999.0
# 7599          7999.0         7999.0
# 10054         6999.0         6999.0
# 8988          6999.0         6999.0
# 8293          6999.0         6999.0
# 6067          6999.0         6999.0
# 6434          6999.0         6999.0
# 11718         6999.0         6999.0
# 4883          6999.0         6999.0
# 7035          6999.0         6999.0
# 13440         6999.0         6999.0
# 10044         6999.0         6999.0
# 10188         6999.0         6999.0
# 4833          6999.0         6999.0
# 2892          6999.0         6999.0
# 3086          5999.0         5999.0
# 6665          5999.0         5999.0
# 7432          2999.0         5999.0
# 3036          5999.0         5999.0
# 12984         5999.0         5999.0

# %%
steam_spy_prices = steamspy_df[['appid', 'current_price', 'initial_price']]
steamworks_prices = steamworks_df[['appid', 'final_price', 'initial_price']]
steamworks_prices.head()
# Out:
#    appid  final_price  initial_price
# 0     10        999.0          999.0
# 1     20        499.0          499.0
# 2     30        499.0          499.0
# 3     40        499.0          499.0
# 4     50        499.0          499.0

# %%
game_prices = (
    steam_spy_prices
    .merge(steamworks_prices[['appid', 'final_price', 'initial_price']], on = 'appid', how = 'left', suffixes=('_spy', '_works'))
)
game_prices.head()
# Out:
#    appid  current_price  initial_price_spy  final_price  initial_price_works
# 0     10          999.0              999.0        999.0                999.0
# 1     20          499.0              499.0        499.0                499.0
# 2     30          499.0              499.0        499.0                499.0
# 3     40          499.0              499.0        499.0                499.0
# 4     50          499.0              499.0        499.0                499.0

# %%
game_prices['current_price'] = np.where(
    game_prices['current_price'] == 0,
    game_prices['final_price'],
    game_prices['current_price']
)

game_prices['initial_price'] = np.where(
    game_prices['initial_price_spy'] == 0,
    game_prices['initial_price_works'],
    game_prices['initial_price_spy']
)
game_prices = game_prices[['appid', 'current_price', 'initial_price']]
game_prices['current_price'] = game_prices['current_price'] / 100
game_prices['initial_price'] = game_prices['initial_price'] / 100
game_prices.rename(columns={'appid': 'game_id'}, inplace= True)
game_prices.sort_values(by = ['initial_price'], ascending = False).head(25)
# Out:
#        game_id  current_price  initial_price
# 14974  3244710         119.99         199.99
# 11144  2914930         199.99         199.99
# 14973  3244700         119.99         199.99
# 14775  3230890         199.99         199.99
# 14534  3214810         199.99         199.99
# 14533  3214800         199.99         199.99
# 2677   1289890         199.99         199.99
# 14773  3230870         119.99         199.99
# 7074   2340720          79.99          79.99
# 5508   2014780          79.99          79.99
# 6005   2140330          69.99          69.99
# 2704   1295660          69.99          69.99
# 9312   2677660          69.99          69.99
# 4515   1778820          69.99          69.99
# 10819  2878980          69.99          69.99
# 6560   2246340          69.99          69.99
# 4562   1790600          69.99          69.99
# 7710   2440510          69.99          69.99
# 5663   2072450          69.99          69.99
# 12369  3043810          69.99          69.99
# 9443   2698940          69.99          69.99
# 9321   2679460          69.99          69.99
# 8344   2537590          69.99          69.99
# 1920   1063730          59.99          59.99
# 1559    924970          59.99          59.99

# %%
del steam_spy_prices
del steamworks_prices

# %% [markdown]
# Splitting dataframe

# %%
user_reviews = []
owners = []
ccu = []

for index, row in steamspy_df.iterrows():
    game_id = int(row['appid'])
    
    user_reviews.append({
        'game_id': game_id,
        'positive': int(row['positive']) if not math.isnan(row['positive']) else float('nan'),
        'negative': int(row['negative']) if not math.isnan(row['negative']) else float('nan')
    })
    
    owners.append({'game_id': game_id, 'owners': str(row['owners'])})
    ccu.append({'game_id': game_id, 'ccu': int(row['ccu'])})

# %%
games_df = pd.DataFrame(names)
dates_df = pd.DataFrame(release_dates)
developers_df = pd.DataFrame(developers)
publishers_df = pd.DataFrame(publishers)
platforms_df = pd.DataFrame(platforms)
genres_df = pd.DataFrame(genres)
metacritic_scores_df = pd.DataFrame(metacritic_scores)
user_reviews_df = pd.DataFrame(user_reviews)
owners_df = pd.DataFrame(owners)
ccu_df = pd.DataFrame(ccu)
game_prices_df = pd.DataFrame(game_prices)

# %%
developers_df['developer'] = developers_df['developer'].str.strip()
publishers_df['publisher'] = publishers_df['publisher'].str.strip()
null_developers = developers_df['developer'].isna().sum()
null_publishers = publishers_df['publisher'].isna().sum()
empty_developers = (developers_df['developer'] == '').sum()
empty_publishers = (publishers_df['publisher'] == '').sum()
print("# of Rows with NULL publishers:", null_publishers)
print("# of Rows with NULL developers:", null_developers)
print(f"# of Empty values in 'publisher': {empty_publishers}")
print(f"# of Empty values in 'developer': {empty_developers}")
print(f"developer (EMPTY): {(developers_df['developer'] == "").sum()}")
print(f"publisher (EMPTY): {(publishers_df['publisher'] == "").sum()}")
print(publishers_df['publisher'].apply(type).value_counts())
# Out:
# # of Rows with NULL publishers: 0
# # of Rows with NULL developers: 0
# # of Empty values in 'publisher': 0
# # of Empty values in 'developer': 0
# developer (EMPTY): 0
# publisher (EMPTY): 0
# publisher
# <class 'str'>    17487
# Name: count, dtype: int64

# %%
non_printable_pattern = re.compile(r'[^\x20-\x7E]')
unique_pub = publishers_df['publisher'].unique().tolist()
problematic_publishers = [pub for pub in unique_pub if non_printable_pattern.search(pub)]
print(problematic_publishers)
# Out:
# []

# %%
print(f'{games_df.head()}\n')
print(f'{game_prices_df.head()}\n')
print(f'{platforms_df.head()}\n')
print(f'{metacritic_scores_df.head()}\n')
print(f'{dates_df.head()}\n')
print(f'{user_reviews_df.head()}\n')
print(f'{owners_df.head()}\n')
print(f'{ccu_df.head()}\n')
print(f'{developers_df.head()}\n')
print(f'{publishers_df.head()}\n')
print(f'{genres_df.head()}\n')
# Out:
#    game_id                       name
# 0       10             Counter-Strike
# 1       20      Team Fortress Classic
# 2       30              Day Of Defeat
# 3       40         Deathmatch Classic
# 4       50  Half-Life: Opposing Force
#
#    game_id  current_price  initial_price
# 0       10           9.99           9.99
# 1       20           4.99           4.99
# 2       30           4.99           4.99
# 3       40           4.99           4.99
# 4       50           4.99           4.99
#
#    game_id platform
# 0       10    linux
# 1       10      mac
# 2       10  windows
# 3       20    linux
# 4       20      mac
#
#    game_id  score
# 0       10   88.0
# 1       30   79.0
# 2       70   96.0
# 3       80   65.0
# 4      240   88.0
#
#    game_id release_date
# 0       10  Nov 1, 2000
# 1       20  Apr 1, 1999
# 2       30  May 1, 2003
# 3       40  Jun 1, 2001
# 4       50  Nov 1, 1999
#
#    game_id  positive  negative
# 0       10    236255      6239
# 1       20      7330      1093
# 2       30      6267       672
# 3       40      2553       527
# 4       50     22337      1116
#
#    game_id                    owners
# 0       10  10,000,000 .. 20,000,000
# 1       20   5,000,000 .. 10,000,000
# 2       30      500,000 .. 1,000,000
# 3       40   5,000,000 .. 10,000,000
# 4       50    2,000,000 .. 5,000,000
#
#    game_id    ccu
# 0       10  14998
# 1       20     62
# 2       30     98
# 3       40      4
# 4       50    101
#
#    game_id         developer
# 0       10             Valve
# 1       20             Valve
# 2       30             Valve
# 3       40             Valve
# 4       50  Gearbox Software
#
#    game_id publisher
# 0       10     Valve
# 1       20     Valve
# 2       30     Valve
# 3       40     Valve
# 4       50     Valve
#
#    game_id   genre
# 0       10  Action
# 1       20  Action
# 2       30  Action
# 3       40  Action
# 4       50  Action

# %% [markdown]
# Splitting owners into min and max values

# %%
owners_df['owners'][0].split(" .. ")[1].strip()
# Out:
# '20,000,000'

# %% [markdown]
# Merging dataframes

# %%
game_metrics_df = (
    games_df
    .merge(user_reviews_df[['game_id', 'positive', 'negative']], on = 'game_id', how = 'left')
    .merge(metacritic_scores_df[['game_id', 'score']], on = 'game_id', how = 'left')
    .merge(ccu_df[['game_id', 'ccu']], on = 'game_id', how = 'left')
    .merge(owners_df[['game_id', 'owners']], on = 'game_id', how= 'left')
)

game_metrics_df[['owners_min', 'owners_max']] = (
    game_metrics_df['owners']
    .str.split(" .. ", expand = True)
    .apply(lambda x: x.str.replace(',','').astype(int))
)

game_metrics_df = game_metrics_df.drop(columns=['owners'])
game_metrics_df = game_metrics_df.rename(columns={'score': 'metacritic_score', 'positive': 'positive_user_score', 'negative': 'negative_user_score'})

# %% [markdown]
# Normalizing release dates

# %%
correct_pattern = r'^[A-Z][a-z]{2} \d{1,2}, \d{4}$'
non_matching_dates = dates_df[~dates_df['release_date'].str.match(correct_pattern, na=False)]
non_matching_dates_count = non_matching_dates.shape[0]
print(f"Number of dates not matching: {non_matching_dates_count}")
pd.set_option('display.max_rows', None)
print(non_matching_dates)
# Out:
# Number of dates not matching: 7030
#        game_id     release_date
# 65       40960
# 86      105600     17 May, 2011
# 87      107100     16 Aug, 2011
# 88      107410     12 Sep, 2013
# 139     230410     26 Mar, 2013
# 154     237930     20 May, 2014
# 164     244850      1 Mar, 2019
# 169     247710  To be announced
# 173     252190      Coming soon
# 211     275390     21 Aug, 2014
# 227     282800     16 May, 2014
# 236     292990         Aug 2014
# 247     301280  To be announced
# 255     304430      7 Jul, 2016
# 256     304770             2025
# 257     305620      1 Aug, 2017
# 261     306910  To be announced
# 317     340020  To be announced
# 337     348930             2024
# 404     374780      Coming soon
# 443     395830      Coming soon
# 449     397950     27 Sep, 2016
# 477     413410     18 Feb, 2016
# 488     420530         Dec 2016
# 495     422610     29 Sep, 2016
# 513     431170      Coming soon
# 520     433220          Q4 2024
# 553     448840             2025
# 554     449460     19 Jan, 2017
# 571     457140     30 Jul, 2019
# 573     458430             2024
# 607     473750      Coming soon
# 623     490110          Q4 2024
# 633     495280     30 Jan, 2017
# 691     522070  To be announced
# 767     565760
# 783     575050         Jan 2017
# 792     579180     16 Apr, 2018
# 801     585690      8 Feb, 2017
# 806     590830  To be announced
# 812     594650     27 Aug, 2019
# 824     598980     22 Feb, 2019
# 851     609920     10 Sep, 2020
# 869     618330      Coming soon
# 875     619820      Coming soon
# 916     635700             2025
# 921     636790      Coming soon
# 931     643370      Coming soon
# 938     648350     11 Jun, 2018
# 955     656540
# 959     656800  To be announced
# 968     659300      Coming soon
# 969     660890      Coming soon
# 972     662000      Coming soon
# 982     666240  To be announced
# 987     668630     20 Sep, 2017
# 997     672890          Q2 2025
# 1028    689760      Coming soon
# 1030    690320      Coming soon
# 1056    702130    February 2025
# 1059    703080      5 Nov, 2019
# 1069    710230    December 2024
# 1097    725780         Jan 2018
# 1104    727690      Coming soon
# 1107    728880      7 Aug, 2018
# 1111    730390     15 Oct, 2020
# 1137    744060     16 Jul, 2018
# 1142    746210          Q1 2025
# 1154    753540  To be announced
# 1165    757940  To be announced
# 1182    762000          Q2 2025
# 1188    763310          Q2 2025
# 1193    764790     30 Aug, 2018
# 1217    771800  To be announced
# 1230    780030  To be announced
# 1235    781450      Coming soon
# 1237    782260  To be announced
# 1240    783550  To be announced
# 1248    788100     14 Jul, 2020
# 1253    789940             2025
# 1259    791770         Mar 2019
# 1260    792290  To be announced
# 1262    793130  To be announced
# 1302    814330          Q4 2024
# 1304    815200  To be announced
# 1310    817800  To be announced
# 1312    818520     January 2025
# 1338    828470      Coming soon
# 1339    828570      Coming soon
# 1378    845230             2024
# 1387    849220      Coming soon
# 1389    850190     15 Feb, 2024
# 1392    851850     16 Jan, 2020
# 1412    860020      Coming soon
# 1421    864170  To be announced
# 1430    867150      Coming soon
# 1462    884670  To be announced
# 1495    895160      Coming soon
# 1499    896410  To be announced
# 1513    904510             2025
# 1514    904850  To be announced
# 1525    908200  To be announced
# 1535    912840     January 2025
# 1538    914210  To be announced
# 1541    916730     30 May, 2019
# 1543    917820  To be announced
# 1552    923020      Coming soon
# 1560    925300  To be announced
# 1561    925500  To be announced
# 1590    943270      Coming soon
# 1614    955010       April 2025
# 1621    956820          Q4 2024
# 1633    964090             2025
# 1638    966260  To be announced
# 1641    968530      Coming soon
# 1643    968770  To be announced
# 1646    969330             2025
# 1650    971700             2025
# 1662    977880     16 Sep, 2021
# 1669    978780     14 Jul, 2020
# 1682    983680  To be announced
# 1697    987140      Coming soon
# 1713    995680          Q1 2025
# 1722   1000030     14 Oct, 2020
# 1734   1002260      Coming soon
# 1739   1005180  To be announced
# 1751   1011590             2024
# 1752   1011850      Coming soon
# 1799   1025560             2025
# 1800   1028320  To be announced
# 1804   1028510      Coming soon
# 1811   1030780  To be announced
# 1814   1031080          Q1 2025
# 1822   1031730      Coming soon
# 1823   1032280  To be announced
# 1852   1040260             2024
# 1861   1042320      Coming soon
# 1869   1043520          Q1 2025
# 1870   1043780      Coming soon
# 1876   1046590      Coming soon
# 1894   1055560             2025
# 1901   1059110      Coming soon
# 1910   1061210  To be announced
# 1930   1066390      Coming soon
# 1931   1066740             2024
# 1938   1068500      Coming soon
# 1939   1068840      Coming soon
# 1943   1070500             2025
# 1955   1075900      Coming soon
# 1976   1081300             2025
# 1978   1082190      Coming soon
# 1994   1085830      Coming soon
# 2002   1088190  To be announced
# 2005   1091500      9 Dec, 2020
# 2013   1094450      Coming soon
# 2014   1094600      Coming soon
# 2026   1097560  To be announced
# 2035   1099510      Coming soon
# 2038   1099900      Coming soon
# 2051   1103820  To be announced
# 2054   1104570  To be announced
# 2059   1105470  To be announced
# 2063   1106680  To be announced
# 2079   1110430  To be announced
# 2082   1111920             2025
# 2086   1113400             2024
# 2088   1114290     20 Jan, 2022
# 2092   1116050             2024
# 2099   1118040          Q1 2025
# 2105   1120330  To be announced
# 2108   1121560     28 Oct, 2019
# 2110   1122230  To be announced
# 2114   1122720     12 Dec, 2019
# 2115   1123160  To be announced
# 2117   1124420      Coming soon
# 2122   1126210      Coming soon
# 2123   1126240  To be announced
# 2144   1133500             2024
# 2163   1141260      Coming soon
# 2165   1142050  To be announced
# 2168   1142570  To be announced
# 2170   1143070             2024
# 2178   1146570  To be announced
# 2183   1148130  To be announced
# 2188   1149450      Coming soon
# 2190   1149620     15 Sep, 2021
# 2194   1150260  To be announced
# 2195   1150530     17 Oct, 2023
# 2200   1151380      Coming soon
# 2206   1153410             2024
# 2216   1155850          Q4 2024
# 2223   1156790      Coming soon
# 2227   1157900  To be announced
# 2228   1158190  To be announced
# 2237   1161590     20 Jul, 2023
# 2238   1162100  To be announced
# 2240   1163020  To be announced
# 2242   1163080      Coming soon
# 2251   1166660  To be announced
# 2254   1167450     13 Feb, 2020
# 2269   1171700      Coming soon
# 2270   1171980             2025
# 2279   1172710             2025
# 2283   1173170  To be announced
# 2286   1173960      Coming soon
# 2287   1173980  To be announced
# 2314   1184790      Coming soon
# 2319   1185380  To be announced
# 2330   1188950      Coming soon
# 2336   1190400     19 May, 2020
# 2343   1192230      Coming soon
# 2345   1192540  To be announced
# 2352   1198710             2025
# 2354   1198970  To be announced
# 2361   1201700      Coming soon
# 2365   1202340  To be announced
# 2374   1204900      Coming soon
# 2377   1205270      Coming soon
# 2378   1205570          Q4 2024
# 2382   1206070  To be announced
# 2386   1207360  To be announced
# 2387   1208630  To be announced
# 2388   1208690      Coming soon
# 2390   1209970  To be announced
# 2396   1211980      Coming soon
# 2397   1213300          Q4 2024
# 2398   1213530      Coming soon
# 2407   1215940      Coming soon
# 2409   1216340          Q3 2025
# 2411   1218210     31 Mar, 2022
# 2418   1220650      Coming soon
# 2424   1221670      Coming soon
# 2426   1222700     18 Jun, 2020
# 2432   1226670          Q1 2025
# 2449   1231560             2024
# 2453   1232060    December 2024
# 2455   1232990      Coming soon
# 2457   1233680             2025
# 2472   1238990  To be announced
# 2488   1244150          Q4 2024
# 2491   1244600  To be announced
# 2492   1244610  To be announced
# 2493   1244620  To be announced
# 2501   1245800  To be announced
# 2505   1248200      Coming soon
# 2509   1249490      Coming soon
# 2530   1255460      Coming soon
# 2534   1256730  To be announced
# 2535   1257030             2025
# 2539   1257290     25 Jan, 2021
# 2540   1257480  To be announced
# 2553   1261370      Coming soon
# 2559   1263170      Coming soon
# 2560   1263210      Coming soon
# 2561   1263240             2024
# 2566   1264940          Q4 2025
# 2570   1266060             2025
# 2571   1266210      Coming soon
# 2574   1266610      Coming soon
# 2583   1268790             2025
# 2599   1272140      Coming soon
# 2608   1273640      Coming soon
# 2611   1274530      Coming soon
# 2614   1274860      Coming soon
# 2616   1275550             2024
# 2622   1276510      Coming soon
# 2625   1277530          Q1 2025
# 2635   1280190      Coming soon
# 2641   1281760      Coming soon
# 2643   1282270  To be announced
# 2655   1284860  To be announced
# 2659   1285190      Coming soon
# 2661   1285360      1 Nov, 2023
# 2674   1289320      Coming soon
# 2675   1289720          Q1 2025
# 2680   1290760      Coming soon
# 2692   1293180     13 Oct, 2022
# 2694   1293480  To be announced
# 2698   1293830      9 Mar, 2021
# 2709   1296530      Coming soon
# 2710   1297440  To be announced
# 2715   1299060          Q1 2025
# 2716   1299290  To be announced
# 2719   1299460             2025
# 2728   1302150      Coming soon
# 2729   1302530          Q4 2024
# 2732   1303940      Coming soon
# 2736   1305260  To be announced
# 2746   1307960      Coming soon
# 2747   1309460      Coming soon
# 2749   1309720      Coming soon
# 2755   1312660  To be announced
# 2756   1312900  To be announced
# 2757   1313140     11 Aug, 2022
# 2758   1313230      Coming soon
# 2759   1313290  To be announced
# 2760   1314190    December 2024
# 2763   1315320          Q4 2024
# 2776   1323140      Coming soon
# 2782   1325580  To be announced
# 2785   1327040      Coming soon
# 2793   1329390      Coming soon
# 2799   1330360             2025
# 2804   1332010     19 Jul, 2022
# 2805   1332100  To be announced
# 2806   1332180      Coming soon
# 2807   1332340          Q4 2024
# 2810   1332780  To be announced
# 2816   1335270      Coming soon
# 2818   1335780      Coming soon
# 2828   1338430      Coming soon
# 2829   1338490          Q4 2024
# 2836   1340050      Coming soon
# 2855   1342690      Coming soon
# 2856   1343010  To be announced
# 2860   1343950      Coming soon
# 2862   1344550     January 2025
# 2863   1344730  To be announced
# 2864   1344990          Q1 2025
# 2866   1345270          Q4 2025
# 2867   1345450      Coming soon
# 2872   1346350      Coming soon
# 2880   1349300  To be announced
# 2890   1352690      Coming soon
# 2891   1352890             2025
# 2893   1354260          Q4 2024
# 2894   1354590  To be announced
# 2897   1354980             2024
# 2898   1355000      Coming soon
# 2899   1355100  To be announced
# 2904   1357320             2025
# 2908   1358660  To be announced
# 2910   1359270  To be announced
# 2913   1360160          Q4 2024
# 2914   1360210      Coming soon
# 2922   1362000             2026
# 2925   1363400  To be announced
# 2930   1363940  To be announced
# 2937   1367710          Q1 2025
# 2938   1367940  To be announced
# 2939   1368010  To be announced
# 2940   1368580      Coming soon
# 2944   1369700  To be announced
# 2949   1371570      Coming soon
# 2954   1372650  To be announced
# 2955   1372660          Q1 2025
# 2956   1373090          Q1 2025
# 2967   1374320             2025
# 2970   1375790          Q1 2025
# 2973   1376200  To be announced
# 2974   1376800      Coming soon
# 2979   1378690      Coming soon
# 2984   1379880      Coming soon
# 2993   1383310  To be announced
# 3001   1384970      Coming soon
# 3002   1385290             2025
# 3003   1385340             2025
# 3005   1385580  To be announced
# 3009   1386630    December 2024
# 3015   1387640      Coming soon
# 3016   1388240  To be announced
# 3018   1388550  To be announced
# 3020   1389140             2025
# 3023   1390420    November 2024
# 3031   1392860             2025
# 3033   1392980  To be announced
# 3034   1393030    November 2024
# 3040   1394780      Coming soon
# 3043   1395380  To be announced
# 3049   1396540      Coming soon
# 3060   1400830  To be announced
# 3063   1401730          Q1 2025
# 3066   1402120     27 Mar, 2023
# 3068   1403250      Coming soon
# 3080   1407640      Coming soon
# 3086   1409840      Coming soon
# 3092   1412150  To be announced
# 3103   1414410      Coming soon
# 3106   1414910             2024
# 3108   1415230      Coming soon
# 3110   1416070  To be announced
# 3117   1418380  To be announced
# 3118   1418750  To be announced
# 3123   1419390      Coming soon
# 3134   1421380  To be announced
# 3147   1426210     25 Mar, 2021
# 3149   1426580  To be announced
# 3151   1427040  To be announced
# 3155   1428090             2025
# 3158   1429080      Coming soon
# 3162   1429880          Q4 2024
# 3166   1430330             2025
# 3168   1431300  To be announced
# 3172   1431910      Coming soon
# 3173   1432050     18 Jan, 2022
# 3176   1432430  To be announced
# 3179   1433020      Coming soon
# 3182   1434840      Coming soon
# 3183   1435100  To be announced
# 3184   1435410      Coming soon
# 3195   1440570      Coming soon
# 3200   1442520  To be announced
# 3201   1442530      Coming soon
# 3204   1443620  To be announced
# 3206   1444080          Q2 2025
# 3209   1445480      Coming soon
# 3211   1446310             2025
# 3212   1446340  To be announced
# 3217   1447250             2025
# 3220   1447650  To be announced
# 3221   1448180             2024
# 3229   1449190  To be announced
# 3231   1449590        July 2025
# 3241   1451050  To be announced
# 3270   1457160      Coming soon
# 3275   1457940  To be announced
# 3280   1459980  To be announced
# 3281   1459990      Coming soon
# 3290   1462990  To be announced
# 3293   1464700      Coming soon
# 3301   1466520             2025
# 3304   1467270  To be announced
# 3305   1467530  To be announced
# 3306   1468110      Coming soon
# 3312   1470740          Q4 2024
# 3315   1471320  To be announced
# 3316   1471650  To be announced
# 3322   1473060          Q1 2025
# 3326   1475300      Coming soon
# 3327   1475310  To be announced
# 3329   1476400             2025
# 3339   1478380      Coming soon
# 3341   1479080      Coming soon
# 3343   1479730             2024
# 3344   1479780      Coming soon
# 3354   1482470  To be announced
# 3356   1482690             2024
# 3359   1483190             2024
# 3377   1488490             2025
# 3379   1489980  To be announced
# 3380   1490800      Coming soon
# 3381   1490930             2025
# 3388   1491800      Coming soon
# 3395   1493220      Coming soon
# 3397   1493440  To be announced
# 3402   1494090          Q1 2025
# 3414   1497430      Coming soon
# 3417   1497460      Coming soon
# 3418   1497910             2025
# 3419   1498060             2025
# 3421   1498550             2025
# 3424   1498850
# 3425   1499010     January 2025
# 3429   1501310             2025
# 3434   1502050      Coming soon
# 3439   1502750          Q4 2025
# 3440   1502910      Coming soon
# 3444   1503110             2025
# 3445   1503170             2025
# 3447   1503490  To be announced
# 3451   1505940             2025
# 3462   1508510       April 2025
# 3465   1509060      Coming soon
# 3472   1510710             2025
# 3474   1511880  To be announced
# 3478   1513030  To be announced
# 3484   1514040             2026
# 3485   1514140             2024
# 3486   1514490      Coming soon
# 3488   1515000      Coming soon
# 3495   1516150      Coming soon
# 3497   1516870  To be announced
# 3505   1519180      Coming soon
# 3509   1520160  To be announced
# 3513   1520440      Coming soon
# 3517   1521360          Q1 2025
# 3519   1522170      Coming soon
# 3521   1522360             2025
# 3523   1522810  To be announced
# 3528   1524620  To be announced
# 3538   1527350      Coming soon
# 3547   1528540    December 2024
# 3550   1529530      Coming soon
# 3553   1530690      Coming soon
# 3557   1532270             2025
# 3561   1533160  To be announced
# 3562   1533420     16 Jun, 2022
# 3565   1534840      Coming soon
# 3568   1536120      Coming soon
# 3571   1537440      Coming soon
# 3572   1537810  To be announced
# 3575   1538010      Coming soon
# 3577   1538300      Coming soon
# 3580   1539050             2025
# 3581   1539720      Coming soon
# 3582   1539860      Coming soon
# 3585   1540370  To be announced
# 3587   1541200  To be announced
# 3598   1546070      Coming soon
# 3599   1546080             2025
# 3605   1547360  To be announced
# 3607   1547540      Coming soon
# 3609   1548180      Coming soon
# 3615   1549990      Coming soon
# 3617   1550150  To be announced
# 3619   1550190          Q1 2025
# 3622   1550920      Coming soon
# 3625   1551190             2025
# 3629   1551460      Coming soon
# 3645   1552500             2025
# 3659   1555790  To be announced
# 3661   1555940          Q3 2025
# 3665   1556360  To be announced
# 3677   1559980      Coming soon
# 3678   1560140  To be announced
# 3679   1560160  To be announced
# 3681   1560520      Coming soon
# 3685   1561740  To be announced
# 3687   1561960      Coming soon
# 3689   1563670      Coming soon
# 3691   1564060  To be announced
# 3694   1564540    December 2024
# 3705   1568010             2025
# 3706   1568530  To be announced
# 3715   1570220             2025
# 3717   1570490    February 2025
# 3718   1570840      Coming soon
# 3722   1571560      Coming soon
# 3724   1571860  To be announced
# 3731   1573560  To be announced
# 3740   1574770  To be announced
# 3744   1575790      Coming soon
# 3751   1577230      Coming soon
# 3752   1577510      Coming soon
# 3755   1578450      Coming soon
# 3757   1578940  To be announced
# 3758   1579210      Coming soon
# 3759   1579340      Coming soon
# 3762   1580240      7 Dec, 2021
# 3767   1581100             2025
# 3770   1582610  To be announced
# 3771   1582630      Coming soon
# 3776   1584240      Coming soon
# 3779   1585100  To be announced
# 3781   1585200      Coming soon
# 3782   1585410      Coming soon
# 3794   1587570      Coming soon
# 3795   1588090      Coming soon
# 3799   1588550             2025
# 3802   1589820      Coming soon
# 3810   1591560  To be announced
# 3812   1591590      Coming soon
# 3818   1593010  To be announced
# 3820   1593060          Q1 2025
# 3832   1594480  To be announced
# 3835   1594960  To be announced
# 3837   1595160  To be announced
# 3838   1595170      Coming soon
# 3839   1595390      Coming soon
# 3841   1595890      Coming soon
# 3844   1597080      Coming soon
# 3849   1597800      Coming soon
# 3850   1597910          Q1 2025
# 3853   1598780          Q1 2025
# 3857   1599420  To be announced
# 3859   1599490      Coming soon
# 3863   1600640      Coming soon
# 3864   1601330             2025
# 3866   1601570          Q1 2025
# 3869   1602030      Coming soon
# 3870   1602090             2025
# 3871   1602160      Coming soon
# 3872   1602520  To be announced
# 3873   1602620  To be announced
# 3874   1602740             2024
# 3881   1604270             2025
# 3885   1605850  To be announced
# 3888   1606970      Coming soon
# 3899   1609370      Coming soon
# 3906   1612590  To be announced
# 3907   1612750      Coming soon
# 3912   1615370      Coming soon
# 3916   1617950  To be announced
# 3919   1618390  To be announced
# 3920   1619310             2024
# 3922   1619580          Q4 2024
# 3923   1619770  To be announced
# 3924   1619920  To be announced
# 3925   1620420          Q2 2026
# 3927   1620720      8 Dec, 2022
# 3928   1620820      Coming soon
# 3931   1621480      Coming soon
# 3932   1621540      Coming soon
# 3935   1621900      Coming soon
# 3936   1621910  To be announced
# 3937   1622310      Coming soon
# 3939   1622570          Q1 2025
# 3940   1622630          Q2 2025
# 3944   1624190      Coming soon
# 3950   1626150  To be announced
# 3951   1626280          Q1 2025
# 3955   1627210      Coming soon
# 3956   1627350      Coming soon
# 3961   1628640             2025
# 3964   1629660  To be announced
# 3966   1630450             2024
# 3969   1631270      Coming soon
# 3971   1631980      Coming soon
# 3976   1637180  To be announced
# 3988   1640400  To be announced
# 3989   1640820      Coming soon
# 3990   1641040      Coming soon
# 3992   1641190      Coming soon
# 4001   1643320  20 листоп. 2024
# 4003   1643800  To be announced
# 4008   1645630  To be announced
# 4009   1646290             2025
# 4012   1647220  To be announced
# 4014   1647640      Coming soon
# 4015   1647660  To be announced
# 4016   1647670  To be announced
# 4020   1648700             2025
# 4029   1650370          Q1 2025
# 4034   1651300      Coming soon
# 4039   1653310      Coming soon
# 4043   1653740  To be announced
# 4053   1656930      Coming soon
# 4054   1657090             2024
# 4055   1657240  To be announced
# 4058   1658090  To be announced
# 4065   1659250             2025
# 4066   1659360      Coming soon
# 4067   1659380  To be announced
# 4069   1660080     January 2025
# 4071   1660510  To be announced
# 4072   1660680      Coming soon
# 4075   1662050          Q1 2025
# 4076   1662160             2025
# 4082   1663850      Coming soon
# 4084   1666110      Coming soon
# 4093   1668340  To be announced
# 4102   1669180             2025
# 4104   1670650             2025
# 4107   1670920  To be announced
# 4112   1671570  To be announced
# 4116   1672320             2025
# 4126   1676840      2 Nov, 2023
# 4142   1682040          Q4 2024
# 4150   1683060      Coming soon
# 4151   1683270          Q1 2025
# 4152   1683390      Coming soon
# 4155   1683450      Coming soon
# 4163   1685270      Coming soon
# 4166   1686260  To be announced
# 4167   1687530          Q1 2025
# 4168   1687540  To be announced
# 4171   1688150  To be announced
# 4174   1688710      Coming soon
# 4177   1689340             2025
# 4178   1689390      Coming soon
# 4181   1690050      Coming soon
# 4187   1691500             2025
# 4201   1695800      Coming soon
# 4203   1697020      Coming soon
# 4204   1697170      Coming soon
# 4205   1697850      Coming soon
# 4206   1697870          Q2 2025
# 4209   1699030      Coming soon
# 4210   1699050  To be announced
# 4211   1699180  To be announced
# 4218   1700930             2025
# 4228   1703280      Coming soon
# 4230   1703610      Coming soon
# 4237   1706740      Coming soon
# 4238   1706950      Coming soon
# 4239   1707170             2025
# 4240   1707680      Coming soon
# 4243   1707990  To be announced
# 4248   1709880          Q4 2024
# 4250   1710110  To be announced
# 4254   1710910  To be announced
# 4255   1710960  To be announced
# 4260   1712640      Coming soon
# 4266   1713730  To be announced
# 4267   1713980      Coming soon
# 4275   1714510      Coming soon
# 4276   1714530      Coming soon
# 4278   1715030      Coming soon
# 4281   1715510  To be announced
# 4285   1716310     22 Oct, 2024
# 4293   1717940      Coming soon
# 4295   1718300    November 2024
# 4297    292030     18 May, 2015
# 4303   1721060      Coming soon
# 4304   1721110  To be announced
# 4314   1723770      Coming soon
# 4320   1725270      Coming soon
# 4323   1726700      Coming soon
# 4326   1726890      Coming soon
# 4330   1727760             2025
# 4333   1728290          Q2 2025
# 4334   1728420      Coming soon
# 4335   1728610  To be announced
# 4336   1729140          Q1 2025
# 4343   1730550  To be announced
# 4353   1732430  To be announced
# 4358   1734110      Coming soon
# 4359   1734130          Q2 2025
# 4360   1735030             2025
# 4361   1735080          Q2 2025
# 4366   1735880      Coming soon
# 4369   1737110      Coming soon
# 4377   1739260  To be announced
# 4385   1742440      Coming soon
# 4387   1742730             2025
# 4391   1743000      Coming soon
# 4403   1747020  To be announced
# 4404   1747190      Coming soon
# 4405   1747470      Coming soon
# 4406   1747630  To be announced
# 4416   1749140    November 2024
# 4417   1749860      Coming soon
# 4418   1750030      Coming soon
# 4419   1750450  To be announced
# 4423   1751950      Coming soon
# 4424   1752530  To be announced
# 4425   1752540             2025
# 4426   1752780  To be announced
# 4427   1752990  To be announced
# 4429   1754550          Q4 2025
# 4437   1756730             2025
# 4438   1756740  To be announced
# 4439   1757000  To be announced
# 4440   1757300             2025
# 4447   1759070             2024
# 4448   1759160      Coming soon
# 4451   1761340      Coming soon
# 4452   1761730  To be announced
# 4457   1763220      Coming soon
# 4458   1763250             2024
# 4460   1765920      Coming soon
# 4465   1766840  To be announced
# 4474   1768860  To be announced
# 4475   1769140             2025
# 4477   1769200      Coming soon
# 4479   1769830  To be announced
# 4480   1769960      Coming soon
# 4482   1770270          Q1 2025
# 4488   1770470  To be announced
# 4490   1771170  To be announced
# 4499   1773220             2025
# 4503   1776200  To be announced
# 4504   1776700          Q1 2025
# 4507   1777480  To be announced
# 4509   1778050  To be announced
# 4512   1778300             2025
# 4516   1778840      Coming soon
# 4517   1778860      Coming soon
# 4519   1778880          Q4 2024
# 4520   1779030          Q1 2025
# 4523   1779910  To be announced
# 4526   1781190  To be announced
# 4532   1782760      Coming soon
# 4533   1782980      Coming soon
# 4537   1784650      Coming soon
# 4539   1785580      Coming soon
# 4540   1785820     10 Mar, 2022
# 4543   1786740      Coming soon
# 4548   1787410             2025
# 4550   1788060             2025
# 4558   1790210  To be announced
# 4561   1790550  To be announced
# 4563   1791580      Coming soon
# 4566   1792200  To be announced
# 4567   1792460  To be announced
# 4575   1794000      Coming soon
# 4576   1794130  To be announced
# 4577   1794240  To be announced
# 4580   1794830      Coming soon
# 4581   1795090      Coming soon
# 4584   1795260          Q1 2026
# 4586   1796190      Coming soon
# 4587   1796310  To be announced
# 4588   1796470  To be announced
# 4590   1796970      Coming soon
# 4596   1799490      Coming soon
# 4600   1800470             2025
# 4603   1801140             2025
# 4605   1801520      Coming soon
# 4613   1803070  To be announced
# 4614   1803110      Coming soon
# 4615   1803360             2024
# 4617   1804010  To be announced
# 4621   1805170             2024
# 4625   1805570          Q1 2025
# 4632   1807950  To be announced
# 4636   1808750  To be announced
# 4637   1808960  To be announced
# 4640   1809960  To be announced
# 4642   1810280      Coming soon
# 4643   1810670          Q4 2024
# 4644   1811000    November 2024
# 4645   1811330  To be announced
# 4646   1811340             2025
# 4657   1813860  To be announced
# 4658   1813980  To be announced
# 4662   1814730          Q1 2025
# 4679   1818480  To be announced
# 4681   1818660      Coming soon
# 4682   1818750     19 Jul, 2022
# 4696   1822240  To be announced
# 4701   1823090      Coming soon
# 4702   1823210  To be announced
# 4704   1823390             2024
# 4705   1823480      Coming soon
# 4707   1823990      Coming soon
# 4708   1824090  To be announced
# 4711   1824480  To be announced
# 4719   1826020  To be announced
# 4724   1826380             2025
# 4727   1826770             2025
# 4729   1826900             2025
# 4731   1827560      Coming soon
# 4732   1827820  To be announced
# 4735   1829270             2025
# 4738   1830320      Coming soon
# 4739   1830430  To be announced
# 4740   1830770  To be announced
# 4742   1831110          Q2 2025
# 4745   1832170          Q2 2025
# 4746   1832270       April 2025
# 4750   1833550      Coming soon
# 4752   1834200  To be announced
# 4754   1834370      Coming soon
# 4758   1835080      Coming soon
# 4761   1835670      Coming soon
# 4769   1838120      Coming soon
# 4771   1838480      Coming soon
# 4773   1839430             2024
# 4775   1839710      Coming soon
# 4777   1839810          Q1 2025
# 4781   1839980      Coming soon
# 4783   1840410      Coming soon
# 4790   1841690  To be announced
# 4791   1841750      Coming soon
# 4792   1842320      Coming soon
# 4793   1842470      Coming soon
# 4797   1843790             2025
# 4798   1843840             2025
# 4799   1844020      Coming soon
# 4803   1844890  To be announced
# 4804   1845250             2025
# 4810   1846720             2024
# 4820   1849940  To be announced
# 4825   1851200    December 2024
# 4829   1853510
# 4836   1855310          Q3 2025
# 4847   1857950      Coming soon
# 4848   1858390      Coming soon
# 4851   1858810      Coming soon
# 4857   1859720      Coming soon
# 4859   1860250      Coming soon
# 4863   1860560      Coming soon
# 4864   1861250      Coming soon
# 4868   1862080          Q4 2024
# 4869   1862760  To be announced
# 4872   1863430    February 2025
# 4873   1864000      Coming soon
# 4874   1864290      Coming soon
# 4875   1864520  To be announced
# 4876   1864830      Coming soon
# 4877   1864880             2025
# 4884   1866300      Coming soon
# 4885   1866420     30 Aug, 2022
# 4886   1866430     30 Aug, 2022
# 4887   1866510     January 2025
# 4889   1866920      Coming soon
# 4896   1868680          Q4 2024
# 4897   1869110      Coming soon
# 4899   1869460      Coming soon
# 4900   1869780  To be announced
# 4905   1870400      Coming soon
# 4909   1871100      Coming soon
# 4910   1871110             2024
# 4915   1872970  To be announced
# 4925   1875320  To be announced
# 4926   1875830     13 Jun, 2024
# 4930   1876850      Coming soon
# 4933   1876930  To be announced
# 4934   1877250  To be announced
# 4945   1880610  To be announced
# 4947   1881280      Coming soon
# 4950   1882130      Coming soon
# 4951   1882190          Q1 2025
# 4952   1882690      Coming soon
# 4953   1882880          Q1 2025
# 4962   1885380  To be announced
# 4965   1885930      Coming soon
# 4966   1885940      Coming soon
# 4975   1890100      Coming soon
# 4977   1890310             2025
# 4981   1892080             2026
# 4982   1892090             2025
# 4983   1892100      Coming soon
# 4987   1892750  To be announced
# 4988   1893390             2025
# 4989   1893440      Coming soon
# 4990   1894100      Coming soon
# 5000   1896310             2025
# 5002   1896760             2025
# 5003   1897030      Coming soon
# 5006   1897450  To be announced
# 5008   1897770      Coming soon
# 5012   1899000      Coming soon
# 5017   1900250          Q1 2025
# 5028   1903340  To be announced
# 5030   1903710             2025
# 5031   1904360      Coming soon
# 5033   1904880             2025
# 5035   1905580      Coming soon
# 5036   1905660      Coming soon
# 5039   1906040      Coming soon
# 5041   1906350     January 2025
# 5043   1906690      Coming soon
# 5044   1906740             2025
# 5049   1908380  To be announced
# 5050   1908530  To be announced
# 5054   1909100      Coming soon
# 5058   1910150          Q2 2025
# 5059   1910280  To be announced
# 5064   1911340      Coming soon
# 5069   1912960  To be announced
# 5073   1914060      Coming soon
# 5075   1914710      Coming soon
# 5078   1915230             2025
# 5079   1915400  To be announced
# 5082   1915870  To be announced
# 5084   1916900          Q1 2025
# 5086   1917850          Q2 2025
# 5088   1918830      Coming soon
# 5093   1919900          Q1 2025
# 5096   1920230  To be announced
# 5098   1921330             2025
# 5104   1922240  To be announced
# 5105   1922260  To be announced
# 5106   1922270  To be announced
# 5107   1922740      Coming soon
# 5117   1925000             2025
# 5124   1925650  To be announced
# 5125   1926610  To be announced
# 5128   1927360          Q1 2025
# 5131   1929170  To be announced
# 5132   1929290          Q1 2025
# 5138   1930630      Coming soon
# 5140   1930980             2024
# 5141   1931180  To be announced
# 5146   1932250          Q1 2026
# 5147   1932300  To be announced
# 5148   1932380  To be announced
# 5154   1933000  To be announced
# 5158   1933830          Q1 2025
# 5160   1934300             2025
# 5161   1934570  To be announced
# 5166   1935330             2024
# 5168   1936750  To be announced
# 5169   1936800      Coming Soon
# 5174   1937880      Coming soon
# 5175   1938050  To be announced
# 5176   1938300     January 2025
# 5180   1939890      Coming soon
# 5181   1940080  To be announced
# 5182   1940360  To be announced
# 5184   1941380          Q1 2025
# 5186   1941540             2025
# 5193   1943730  To be announced
# 5194   1944040      Coming soon
# 5199   1946440      Coming soon
# 5200   1946760  To be announced
# 5206   1947220  To be announced
# 5210   1948490          Q1 2025
# 5214   1948940  To be announced
# 5216   1949310      Coming soon
# 5218   1950230          Q1 2025
# 5221   1951210  To be announced
# 5225   1951780      Coming soon
# 5231   1952620  To be announced
# 5232   1953230  To be announced
# 5236   1954160  To be announced
# 5237   1955850             2025
# 5246   1957760  To be announced
# 5248   1957830  To be announced
# 5261   1961600             2025
# 5263   1962010  To be announced
# 5264   1962210  To be announced
# 5265   1962700             2025
# 5269   1963850      Coming soon
# 5270   1964080      Coming soon
# 5277   1964930  To be announced
# 5279   1965470  To be announced
# 5280   1965620      Coming soon
# 5285   1967070  To be announced
# 5287   1967820    December 2024
# 5288   1968180      Coming soon
# 5295   1969170       April 2025
# 5298   1969810  To be announced
# 5300   1970220  To be announced
# 5302   1971310      Coming soon
# 5303   1971670      Coming soon
# 5305   1971900      Coming soon
# 5308   1972450          Q1 2025
# 5311   1973420      Coming soon
# 5314   1973990          Q2 2025
# 5319   1974560             2024
# 5322   1975380             2024
# 5323   1975520     January 2025
# 5324   1975580  To be announced
# 5325   1975640             2024
# 5326   1975650      Coming soon
# 5328   1976110             2025
# 5330   1976890          Q1 2025
# 5332   1977000  To be announced
# 5334   1977610  To be announced
# 5337   1978590     11 Jul, 2024
# 5339   1979200          Q4 2024
# 5341   1980120      Coming soon
# 5342   1980460          Q1 2025
# 5354   1984210      Coming soon
# 5356   1984440      Coming soon
# 5357   1984800      Coming soon
# 5362   1985740          Q1 2025
# 5364   1986290             2025
# 5365   1986560  To be announced
# 5377   1989500      Coming soon
# 5383   1989720      Coming soon
# 5384   1989760      Coming soon
# 5385   1989970  To be announced
# 5398   1991460      Coming soon
# 5404   1993050      Coming soon
# 5407   1994040             2025
# 5408   1994060             2025
# 5410   1994410      Coming soon
# 5411   1994650  To be announced
# 5418   1996090  To be announced
# 5419   1996390  To be announced
# 5421   1996520  To be announced
# 5422   1996540  To be announced
# 5425   1997330  To be announced
# 5426   1997400  To be announced
# 5427   1997410          Q1 2025
# 5430   1997440    December 2024
# 5442   1999660      Coming soon
# 5449   2000210             2024
# 5451   2000780       April 2025
# 5453   2001070             2024
# 5455   2001430      Coming soon
# 5457   2002270      Coming soon
# 5459   2002730      Coming soon
# 5463   2003450      Coming soon
# 5468   2004060      Coming soon
# 5481   2007350             2025
# 5482   2007430      Coming soon
# 5488   2008670      Coming soon
# 5491   2009160             2025
# 5496   2009940  To be announced
# 5497   2010010          Q1 2025
# 5502   2011960          Q1 2026
# 5504   2012390  To be announced
# 5505   2012600      Coming soon
# 5512   2015470  To be announced
# 5513   2015580    February 2025
# 5515   2015760  To be announced
# 5519   2017040      Coming soon
# 5520   2017120          Q1 2025
# 5524   2017940  To be announced
# 5525   2019010          Q1 2025
# 5527   2019340      Coming soon
# 5529   2019620      Coming soon
# 5531   2019760      Coming soon
# 5532   2020040          Q4 2024
# 5533   2020400      Coming soon
# 5535   2021390      Coming soon
# 5539   2022610  To be announced
# 5542   2023420  To be announced
# 5545   2024080          Q4 2024
# 5551   2025800    December 2024
# 5552   2025870  To be announced
# 5554   2026040  To be announced
# 5558   2026820          Q1 2025
# 5559   2027030  To be announced
# 5563   2027760  To be announced
# 5567   2050710      Coming soon
# 5569   2051890          Q4 2024
# 5570   2052300  To be announced
# 5571   2052650  To be announced
# 5576   2052790      Coming soon
# 5577   2052920             2024
# 5578   2052970  To be announced
# 5580   2053910  To be announced
# 5581   2054380             2025
# 5585   2055060      Coming soon
# 5586   2055360      Coming soon
# 5588   2056130          Q1 2025
# 5589   2056180          Q2 2025
# 5590   2056200      Coming soon
# 5594   2057030      Coming soon
# 5597   2058070             2024
# 5599   2058340          Q4 2024
# 5600   2058540      Coming soon
# 5601   2058730      Coming soon
# 5603   2059260      Coming soon
# 5606   2060110      Coming soon
# 5613   2062030             2025
# 5616   2063390      Coming soon
# 5619   2063900      Coming soon
# 5622   2064310  To be announced
# 5625   2065170    December 2024
# 5626   2065280             2025
# 5627   2065720      Coming soon
# 5630   2065830             2025
# 5632   2066020      7 Nov, 2022
# 5635   2066980    December 2024
# 5636   2067070          Q4 2024
# 5637   2067120             2025
# 5645   2068080      Coming soon
# 5646   2068650             2025
# 5648   2068840      Coming soon
# 5651   2069330             2026
# 5657   2070580    November 2024
# 5658   2070860      Coming soon
# 5660   2071400      Coming soon
# 5662   2071790  To be announced
# 5665   2072980          Q4 2024
# 5666   2073250      Coming soon
# 5667   2073330  To be announced
# 5670   2073910      Coming soon
# 5674   2074620      Coming soon
# 5676   2075460             2025
# 5678   2075640      Coming soon
# 5682   2076210      Coming soon
# 5684   2076380      Coming soon
# 5687   2076650  To be announced
# 5690   2077750      Coming soon
# 5695   2078200      Coming soon
# 5696   2078230             2025
# 5698   2079980      Coming soon
# 5702   2080890      Coming soon
# 5705   2081720  To be announced
# 5706   2082160      Coming soon
# 5708   2082690          Q4 2025
# 5709   2083030      Coming soon
# 5712   2083940          Q4 2024
# 5716   2084360  To be announced
# 5718   2085080      Coming soon
# 5720   2085540             2024
# 5721   2085580  To be announced
# 5722   2085620          Q1 2025
# 5723   2085640      Coming soon
# 5724   2085660          Q1 2025
# 5726   2085980      Coming soon
# 5728   2086680          Q1 2025
# 5730   2087230      Coming soon
# 5731   2087500      Coming soon
# 5732   2087880             2025
# 5733   2088300      Coming soon
# 5736   2088540      Coming soon
# 5737   2088550      Coming soon
# 5740   2088810      Coming soon
# 5744   2089630      Coming soon
# 5746   2089990  To be announced
# 5747   2090210  To be announced
# 5752   2092340      Coming soon
# 5753   2092390      Coming soon
# 5754   2092970          Q1 2025
# 5757   2093520          Q3 2025
# 5758   2093580  To be announced
# 5759   2093630    February 2025
# 5760   2093800  To be announced
# 5767   2094540      Coming soon
# 5771   2094900      Coming soon
# 5773   2094930      Coming soon
# 5781   2096260  To be announced
# 5783   2096780      Coming soon
# 5785   2097170      Coming soon
# 5787   2097570          Q2 2025
# 5789   2097950  To be announced
# 5791   2098160          Q1 2025
# 5796   2099570      Coming soon
# 5800   2099750      Coming soon
# 5803   2100020  To be announced
# 5804   2100400             2025
# 5805   2100640      Coming soon
# 5807   2101100  To be announced
# 5809   2101390  To be announced
# 5810   2101470      Coming soon
# 5812   2101960             2025
# 5813   2102040             2025
# 5818   2103110      Coming soon
# 5822   2103440      Coming soon
# 5825   2103950             2025
# 5827   2105260      Coming soon
# 5829   2105620      Coming soon
# 5831   2105890             2025
# 5833   2106490  To be announced
# 5836   2107030      Coming soon
# 5839   2107540      Coming soon
# 5847   2109770             2024
# 5848   2110390             2025
# 5850   2111080  To be announced
# 5853   2111430             2024
# 5861   2113350             2025
# 5863   2114100      Coming soon
# 5864   2114160          Q2 2025
# 5876   2116350      Coming soon
# 5879   2116590      Coming soon
# 5880   2116610          Q1 2025
# 5883   2117110      Coming soon
# 5885   2117430  To be announced
# 5888   2118230          Q4 2025
# 5893   2118680      Coming soon
# 5901   2120220  To be announced
# 5903   2120300      Coming soon
# 5904   2120640  To be announced
# 5905   2121320          Q4 2024
# 5906   2121450             2025
# 5910   2122780  To be announced
# 5911   2122830      Coming soon
# 5913   2123330  To be announced
# 5914   2123400      Coming soon
# 5915   2123410          Q2 2025
# 5916   2124100      Coming soon
# 5917   2124110      Coming soon
# 5919   2124150      Coming soon
# 5920   2124200  To be announced
# 5921   2124480             2025
# 5922   2124500  To be announced
# 5923   2125110      Coming soon
# 5925   2126090          Q1 2025
# 5926   2126190      Coming soon
# 5928   2127130      Coming soon
# 5930   2128230  To be announced
# 5939   2129530      Coming soon
# 5942   2130800             2025
# 5946   2131290      Coming soon
# 5947   2132260  To be announced
# 5950   2132560          Q4 2024
# 5952   2132890  To be announced
# 5955   2133520          Q1 2025
# 5957   2133620      Coming soon
# 5958   2133760             2025
# 5959   2133830             2024
# 5960   2133850          Q2 2025
# 5963   2134370  To be announced
# 5964   2134530       April 2025
# 5966   2134690      Coming soon
# 5968   2134850      Coming soon
# 5971   2135280             2025
# 5972   2135650      Coming soon
# 5976   2136060      Coming soon
# 5978   2136420  To be announced
# 5981   2136910   September 2026
# 5985   2137670      Coming soon
# 5989   2137880      Coming soon
# 5991   2138360             2025
# 5996   2139040      Coming soon
# 5997   2139090  To be announced
# 5998   2139330      Coming soon
# 5999   2139410      Coming soon
# 6006   2140470  To be announced
# 6008   2140620      Coming soon
# 6012   2141280             2025
# 6014   2141620      Coming soon
# 6016   2142420             2025
# 6021   2143600             2025
# 6023   2143870    December 2024
# 6026   2144580          Q3 2025
# 6027   2144610             2026
# 6030   2144810  To be announced
# 6033   2145880      Coming soon
# 6034   2145980  To be announced
# 6036   2146310  To be announced
# 6037   2146390      Coming soon
# 6038   2146470      Coming soon
# 6044   2147690  To be announced
# 6045   2147830          Q4 2026
# 6053   2150210      Coming soon
# 6054   2150490          Q4 2024
# 6059   2151010  To be announced
# 6060   2151140  To be announced
# 6065   2152740      Coming soon
# 6066   2152830      Coming soon
# 6069   2153690      Coming soon
# 6073   2154420  To be announced
# 6078   2156790             2025
# 6080   2157470             2025
# 6084   2157710      Coming soon
# 6091   2159170      Coming soon
# 6096   2159900  To be announced
# 6098   2160070  To be announced
# 6099   2160250      Coming soon
# 6104   2161830  To be announced
# 6106   2162570    December 2025
# 6113   2164050             2025
# 6116   2164500      Coming soon
# 6118   2164720  To be announced
# 6120   2165040          Q4 2025
# 6124   2165810          Q4 2024
# 6131   2166730  To be announced
# 6136   2168120          Q1 2025
# 6137   2168190      Coming soon
# 6139   2168330      Coming soon
# 6144   2169950      Coming soon
# 6145   2170060  To be announced
# 6148   2171030  To be announced
# 6149   2171640          Q1 2025
# 6150   2171660      Coming soon
# 6159   2173460             2024
# 6160   2173770  To be announced
# 6161   2173930          Q4 2024
# 6162   2174060             2025
# 6163   2174430  To be announced
# 6166   2174560      Coming soon
# 6167   2174750  To be announced
# 6169   2174850             2025
# 6172   2175480             2025
# 6174   2175540     11 Sep, 2024
# 6175   2175670      Coming soon
# 6178   2176460          Q4 2024
# 6179   2176490          Q2 2025
# 6186   2176920  To be announced
# 6188   2177010      Coming soon
# 6191   2178230      Coming soon
# 6192   2178290  To be announced
# 6198   2178990          Q1 2025
# 6201   2179210          Q1 2025
# 6203   2179370          Q1 2025
# 6204   2179390             2024
# 6205   2179480      Coming soon
# 6209   2180850      Coming soon
# 6217   2182470      Coming soon
# 6218   2182610          Q1 2025
# 6222   2183220  To be announced
# 6223   2183670  To be announced
# 6224   2183900      9 Sep, 2024
# 6225   2184020      Coming soon
# 6228   2184290      Coming soon
# 6231   2185030     January 2025
# 6236   2186360     January 2025
# 6238   2186580      Coming soon
# 6240   2186690  To be announced
# 6243   2187290      5 Apr, 2023
# 6246   2187420  To be announced
# 6247   2187450  To be announced
# 6255   2188870             2025
# 6258   2189260  To be announced
# 6259   2189310  To be announced
# 6260   2189430             2025
# 6262   2190150      Coming soon
# 6269   2190700      Coming soon
# 6270   2190920      Coming soon
# 6271   2191050      Coming soon
# 6273   2191280  To be announced
# 6274   2191500             2025
# 6277   2191690             2024
# 6278   2191720      Coming soon
# 6280   2192020      Coming soon
# 6281   2192080  To be announced
# 6285   2192970      Coming soon
# 6288   2193150  To be announced
# 6290   2193530  To be announced
# 6294   2194780    December 2024
# 6295   2194790             2024
# 6303   2196030      Coming soon
# 6305   2196750      Coming soon
# 6308   2197240             2025
# 6309   2197740      Coming soon
# 6313   2198120      Coming soon
# 6319   2199080             2025
# 6323   2199790      Coming soon
# 6324   2199980      Coming soon
# 6325   2200340          Q1 2025
# 6328   2201470             2025
# 6329   2201500      Coming soon
# 6330   2201620             2025
# 6333   2202010          Q4 2024
# 6335   2202650  To be announced
# 6338   2202980  To be announced
# 6340   2203830             2025
# 6342   2204210      Coming soon
# 6349   2205550    November 2024
# 6351   2205930      Coming soon
# 6357   2206380      Coming soon
# 6359   2206400      Coming soon
# 6361   2206730      Coming soon
# 6363   2207230    December 2024
# 6364   2207440             2024
# 6365   2207580      Coming soon
# 6369   2208360  To be announced
# 6372   2209140      Coming soon
# 6373   2209180          Q4 2025
# 6375   2209360          Q1 2025
# 6376   2209390      Coming soon
# 6377   2209620      Coming soon
# 6383   2210520             2025
# 6388   2211920  To be announced
# 6393   2212670      Coming soon
# 6397   2213300     20 Jul, 2023
# 6398   2213330             2025
# 6401   2213700             2025
# 6403   2214180      Coming soon
# 6404   2214220  To be announced
# 6406   2214900      Coming soon
# 6414   2216840      Coming soon
# 6427   2219390             2025
# 6429   2219600  To be announced
# 6430   2219620      Coming soon
# 6434   2220560          Q1 2025
# 6436   2221060  To be announced
# 6438   2221390  To be announced
# 6441   2221780          Q4 2024
# 6443   2222090  To be announced
# 6445   2222550      Coming soon
# 6446   2223150      Coming soon
# 6447   2223420          Q4 2024
# 6448   2223980             2025
# 6456   2226460      Coming soon
# 6457   2226730             2025
# 6459   2227100  To be announced
# 6461   2228090  To be announced
# 6465   2228490      Coming soon
# 6467   2228900             2024
# 6474   2230450  To be announced
# 6475   2230530          Q2 2025
# 6477   2230960      Coming soon
# 6478   2231070      Coming soon
# 6481   2231680      Coming soon
# 6484   2232830      Coming soon
# 6486   2233390             2024
# 6489   2233920      Coming soon
# 6490   2234140      Coming soon
# 6492   2234300      Coming soon
# 6493   2234780    February 2025
# 6494   2235490  To be announced
# 6495   2235550             2025
# 6501   2236450  To be announced
# 6502   2237320  To be announced
# 6505   2238170             2024
# 6507   2238400  To be announced
# 6509   2238470             2025
# 6513   2239130      Coming soon
# 6515   2239710             2025
# 6517   2240080      Coming soon
# 6523   2240950             2025
# 6524   2241000          Q2 2025
# 6527   2241380      Coming soon
# 6529   2241610  To be announced
# 6530   2241660  To be announced
# 6532   2242180  To be announced
# 6533   2242240      Coming soon
# 6534   2242270             2025
# 6538   2242970          Q4 2024
# 6540   2243330      Coming soon
# 6543   2243690  To be announced
# 6544   2243700      Coming soon
# 6548   2244240      Coming soon
# 6552   2244650             2025
# 6556   2245180  To be announced
# 6561   2246370             2025
# 6562   2247220             2025
# 6563   2247860             2025
# 6565   2248150  To be announced
# 6566   2248170  To be announced
# 6567   2248230      Coming soon
# 6568   2248280          Q1 2025
# 6573   2248960  To be announced
# 6576   2249600      Coming soon
# 6577   2249870      Coming soon
# 6580   2250230      Coming soon
# 6581   2250330             2025
# 6586   2251220      Coming soon
# 6587   2251400  To be announced
# 6590   2253100      Coming soon
# 6592   2253340  To be announced
# 6598   2254410      Coming soon
# 6601   2254950      Coming soon
# 6602   2254990             2025
# 6603   2255090  To be announced
# 6604   2255370             2025
# 6608   2256340          Q2 2025
# 6609   2256350      Coming soon
# 6613   2256840      Coming soon
# 6615   2257010             2024
# 6616   2257440      Coming soon
# 6618   2257850      Coming soon
# 6626   2259390          Q1 2026
# 6627   2259590      Coming soon
# 6628   2259620  To be announced
# 6629   2260170          Q4 2024
# ...
# 15853  3294060    December 2024
# 15854  3294100          Q1 2025
# 15855  3294130             2025
# 15856  3294180      Coming soon
# 15857  3294210          Q4 2024
# 15858  3294220      Coming soon
# 15859  3294270      Coming soon
# 15861  3294300      Coming soon
# 15865  3294540      Coming soon
# 15866  3294550      Coming soon
# 15867  3294570             2025
# 15868  3294610      Coming soon
# 15869  3294620    November 2024
# 15872  3294750      Coming soon
# 15875  3294930          Q4 2024
# 15876  3294970  To be announced
# 15877  3295010  To be announced
# 15880  3295350             2025
# 15881  3295420  To be announced
# 15882  3295490      Coming soon
# 15883  3295530             2025
# 15884  3295680  To be announced
# 15885  3295700  To be announced
# 15887  3295760      Coming soon
# 15890  3295930      Coming soon
# 15892  3296010             2025
# 15893  3296050      Coming soon
# 15894  3296070  To be announced
# 15896  3296160             2024
# 15897  3296180      Coming soon
# 15898  3296240      Coming soon
# 15899  3296250      Coming soon
# 15901  3296450             2025
# 15902  3296560  To be announced
# 15903  3296610  To be announced
# 15908  3296920          Q1 2025
# 15910  3297010      Coming soon
# 15911  3297030      Coming soon
# 15914  3297120      Coming soon
# 15915  3297200             2025
# 15916  3297210      Coming soon
# 15917  3297250      Coming soon
# 15918  3297310      Coming soon
# 15919  3297340      Coming soon
# 15920  3297410      Coming soon
# 15921  3297500      Coming soon
# 15922  3297510             2025
# 15923  3297730      Coming soon
# 15924  3297740      Coming soon
# 15925  3297800    December 2025
# 15926  3297850      Coming soon
# 15927  3297870      Coming soon
# 15928  3297900      Coming soon
# 15931  3298030          Q4 2024
# 15933  3298130  To be announced
# 15934  3298230      Coming soon
# 15937  3298410      Coming soon
# 15938  3298420  To be announced
# 15939  3298460      Coming soon
# 15941  3298560             2025
# 15942  3298570      Coming soon
# 15943  3298590    November 2024
# 15944  3298640      Coming soon
# 15945  3298650      Coming soon
# 15946  3298660          Q4 2024
# 15947  3298710      Coming soon
# 15948  3298720      Coming soon
# 15949  3298760    November 2024
# 15952  3298840  To be announced
# 15953  3298910  To be announced
# 15954  3298920             2025
# 15955  3298940      Coming soon
# 15957  3299160          Q2 2025
# 15958  3299190      Coming soon
# 15959  3299230      Coming soon
# 15962  3299470      Coming soon
# 15963  3299500      Coming soon
# 15968  3299750          Q4 2024
# 15969  3299760      Coming soon
# 15970  3299810  To be announced
# 15972  3299870      Coming soon
# 15973  3299880          Q4 2024
# 15976  3299960      Coming soon
# 15977  3300020          Q4 2024
# 15978  3300050             2025
# 15979  3300060      Coming soon
# 15980  3300090      Coming soon
# 15984  3300410      Coming soon
# 15985  3300470      Coming soon
# 15987  3300510      Coming soon
# 15988  3300590      Coming soon
# 15989  3300620      Coming soon
# 15990  3300670          Q4 2024
# 15991  3300800             2025
# 15992  3300830             2025
# 15995  3300950             2024
# 15996  3301000             2025
# 15997  3301020             2025
# 15998  3301040      Coming soon
# 15999  3301070  To be announced
# 16000  3301090      Coming soon
# 16001  3301100      Coming soon
# 16002  3301140      Coming soon
# 16003  3301160      Coming soon
# 16004  3301180     January 2025
# 16005  3301210  To be announced
# 16006  3301350             2025
# 16007  3301360      Coming soon
# 16008  3301370      Coming soon
# 16009  3301500      Coming soon
# 16010  3301520      Coming soon
# 16011  3301530      Coming soon
# 16012  3301650             2025
# 16014  3301670      Coming soon
# 16015  3301810             2026
# 16016  3301850      Coming soon
# 16017  3301910      Coming soon
# 16018  3301970    February 2025
# 16019  3301980      Coming soon
# 16020  3302080       March 2025
# 16021  3302090    November 2024
# 16022  3302160             2025
# 16023  3302190      Coming soon
# 16025  3302360       April 2026
# 16026  3302380             2026
# 16027  3302400       April 2026
# 16028  3302410  To be announced
# 16031  3302570      Coming soon
# 16033  3302620      Coming soon
# 16036  3302740      Coming soon
# 16037  3302850      Coming soon
# 16038  3302910      Coming soon
# 16039  3302950  To be announced
# 16040  3303010  To be announced
# 16043  3303140      Coming soon
# 16045  3303250      Coming soon
# 16048  3303340      Coming soon
# 16049  3303350      Coming soon
# 16050  3303370      Coming soon
# 16053  3303630      Coming soon
# 16054  3303660      Coming soon
# 16056  3303720             2025
# 16058  3303780      Coming soon
# 16060  3303870             2025
# 16061  3303890             2025
# 16062  3303940             2025
# 16063  3304010             2025
# 16065  3304070          Q4 2026
# 16066  3304280  To be announced
# 16067  3304350      Coming soon
# 16069  3304400    November 2024
# 16070  3304410      Coming soon
# 16071  3304430      Coming soon
# 16073  3304460      Coming soon
# 16076  3304540             2025
# 16077  3304570      Coming soon
# 16078  3304640  To be announced
# 16080  3304710      Coming soon
# 16081  3304750      Coming soon
# 16082  3304780          Q1 2025
# 16083  3304830    December 2024
# 16084  3304930      Coming soon
# 16085  3304950    November 2024
# 16086  3304980  To be announced
# 16087  3304990    November 2024
# 16088  3305060  To be announced
# 16089  3305070      Coming soon
# 16090  3305080      Coming soon
# 16091  3305190      Coming soon
# 16092  3305200      Coming soon
# 16093  3305230      Coming soon
# 16096  3305500       March 2025
# 16097  3305530      Coming soon
# 16098  3305540      Coming soon
# 16099  3305640      Coming soon
# 16100  3305650          Q1 2025
# 16101  3305700  To be announced
# 16102  3305740      Coming soon
# 16103  3305750  To be announced
# 16105  3305930             2025
# 16106  3306080    November 2024
# 16108  3306120    December 2024
# 16109  3306160      Coming soon
# 16110  3306180    November 2024
# 16111  3306300      Coming soon
# 16112  3306400             2025
# 16113  3306460      Coming soon
# 16114  3306470      Coming soon
# 16115  3306780      Coming soon
# 16117  3306890      Coming soon
# 16120  3306920             2025
# 16121  3306950      Coming soon
# 16122  3307010      Coming soon
# 16123  3307020      Coming soon
# 16124  3307110             2025
# 16126  3307230       March 2025
# 16127  3307240             2025
# 16128  3307250      Coming soon
# 16129  3307270    November 2024
# 16130  3307350      Coming soon
# 16131  3307410      Coming soon
# 16132  3307430      Coming soon
# 16133  3307440      Coming soon
# 16134  3307460      Coming soon
# 16136  3307670       March 2025
# 16138  3307860             2025
# 16139  3307880      Coming soon
# 16140  3307980      Coming soon
# 16141  3308140      Coming soon
# 16144  3308210      Coming soon
# 16145  3308220      Coming soon
# 16146  3308230             2025
# 16147  3308240      Coming soon
# 16148  3308280    December 2024
# 16149  3308350    November 2024
# 16150  3308380      Coming soon
# 16152  3308560      Coming soon
# 16153  3308580      Coming soon
# 16155  3308940      Coming soon
# 16156  3308950      Coming soon
# 16157  3309130      Coming soon
# 16159  3309210      Coming soon
# 16160  3309220      Coming soon
# 16161  3309240      Coming soon
# 16162  3309250      Coming soon
# 16163  3309290  To be announced
# 16164  3309380      Coming soon
# 16166  3309460          Q4 2024
# 16167  3309470      Coming soon
# 16168  3309510             2024
# 16169  3309620    November 2024
# 16171  3309870  To be announced
# 16172  3309880          Q2 2026
# 16174  3310020      Coming soon
# 16175  3310100      Coming soon
# 16176  3310110      Coming soon
# 16177  3310160     January 2025
# 16179  3310230  To be announced
# 16180  3310260      Coming soon
# 16181  3310330     January 2025
# 16182  3310350      Coming soon
# 16183  3310390  To be announced
# 16184  3310520  To be announced
# 16185  3310540      Coming soon
# 16186  3310590             2025
# 16187  3310680      Coming soon
# 16189  3310850  To be announced
# 16190  3310880      Coming soon
# 16192  3310930       March 2025
# 16193  3310990      Coming soon
# 16194  3311180      Coming soon
# 16195  3311220    December 2024
# 16197  3311470          Q4 2025
# 16198  3311510    December 2024
# 16200  3311610      Coming soon
# 16201  3311690     January 2025
# 16203  3311840      Coming soon
# 16204  3312020      Coming soon
# 16205  3312030  To be announced
# 16206  3312100      Coming soon
# 16207  3312180  To be announced
# 16208  3312250      Coming soon
# 16209  3312300      Coming soon
# 16210  3312330      Coming soon
# 16211  3312350  To be announced
# 16213  3312420          Q1 2025
# 16214  3312430  To be announced
# 16216  3312530      Coming soon
# 16218  3312570      Coming soon
# 16219  3312640      Coming soon
# 16220  3312670      Coming soon
# 16222  3312890  To be announced
# 16223  3313130      Coming soon
# 16224  3313180    November 2024
# 16225  3313200      Coming soon
# 16227  3313230      Coming soon
# 16228  3313290    November 2024
# 16230  3313430  To be announced
# 16232  3313530      Coming soon
# 16234  3313640             2025
# 16235  3313720          Q4 2025
# 16236  3313780      Coming soon
# 16237  3313810    November 2024
# 16238  3313840      Coming soon
# 16240  3313880  To be announced
# 16241  3314040    November 2024
# 16242  3314270             2025
# 16244  3314340      Coming soon
# 16245  3314350    November 2024
# 16246  3314420    November 2024
# 16248  3314630             2025
# 16249  3314780      Coming soon
# 16250  3314790          Q1 2025
# 16251  3314980             2024
# 16252  3315020  To be announced
# 16253  3315130      Coming soon
# 16254  3315190      Coming soon
# 16255  3315330          Q2 2025
# 16256  3315400      Coming soon
# 16257  3315490          Q1 2025
# 16258  3315600      Coming soon
# 16259  3315630      Coming soon
# 16260  3315700  To be announced
# 16261  3315840      Coming soon
# 16263  3315900          Q4 2024
# 16265  3316010      Coming soon
# 16266  3316020             2025
# 16268  3316170    November 2024
# 16269  3316190  To be announced
# 16271  3316330             2025
# 16272  3316340    November 2024
# 16273  3316470  To be announced
# 16274  3316580    November 2024
# 16276  3316620    December 2024
# 16277  3316650    November 2024
# 16279  3316690       March 2025
# 16280  3316700      Coming soon
# 16282  3316800      Coming soon
# 16283  3316840          Q4 2024
# 16284  3316880          Q1 2025
# 16285  3316910      Coming soon
# 16286  3316960             2025
# 16287  3317120  To be announced
# 16291  3317370      Coming soon
# 16292  3317410      Coming soon
# 16295  3317450      Coming soon
# 16296  3317520    November 2024
# 16297  3317590      Coming soon
# 16298  3317720  To be announced
# 16299  3317740    November 2024
# 16300  3317780          Q1 2025
# 16301  3317820  To be announced
# 16302  3317890    November 2024
# 16303  3317930      Coming soon
# 16304  3318140       March 2025
# 16305  3318380      Coming soon
# 16307  3318500             2025
# 16308  3318510      Coming soon
# 16310  3319000       March 2025
# 16311  3319040      Coming soon
# 16312  3319050      Coming soon
# 16313  3319070    November 2024
# 16314  3319230      Coming soon
# 16315  3319290    November 2024
# 16316  3319330      Coming soon
# 16317  3319460             2025
# 16321  3319710    December 2024
# 16322  3319750      Coming soon
# 16323  3319780    December 2024
# 16324  3319790      Coming soon
# 16325  3320140          Q1 2028
# 16326  3320200      Coming soon
# 16327  3320260      Coming soon
# 16328  3320270      Coming soon
# 16329  3320340    December 2024
# 16330  3320380          Q4 2024
# 16331  3320440  To be announced
# 16332  3320490          Q2 2025
# 16334  3320520    December 2024
# 16335  3320540         May 2025
# 16336  3320840             2025
# 16338  3320930     January 2025
# 16339  3320940          Q4 2024
# 16340  3320960             2025
# 16341  3321000      Coming soon
# 16342  3321020             2025
# 16343  3321050      Coming soon
# 16344  3321150  To be announced
# 16345  3321190  To be announced
# 16346  3321280  To be announced
# 16347  3321400      Coming soon
# 16348  3321440  To be announced
# 16349  3321480          Q1 2025
# 16351  3321610      Coming soon
# 16352  3321770      Coming soon
# 16353  3321790      Coming soon
# 16354  3322640      Coming soon
# 16355  3322670  To be announced
# 16356  3322770      Coming soon
# 16358  3322900      Coming soon
# 16359  3322930      Coming soon
# 16360  3322950      Coming soon
# 16361  3322980      Coming soon
# 16363  3323020      Coming soon
# 16364  3323030      Coming soon
# 16365  3323040          Q1 2025
# 16367  3323180      Coming soon
# 16368  3323190             2025
# 16369  3323260             2025
# 16370  3323470      Coming soon
# 16371  3323590    November 2024
# 16372  3323630      Coming soon
# 16373  3323650             2025
# 16374  3323670      Coming soon
# 16375  3323740          Q2 2025
# 16377  3323970             2025
# 16378  3324040    November 2024
# 16379  3324130    December 2024
# 16380  3324140             2026
# 16381  3324150      Coming soon
# 16383  3324450      Coming soon
# 16385  3324530      Coming soon
# 16386  3324570      Coming soon
# 16387  3324580      Coming soon
# 16388  3324610          Q4 2025
# 16390  3324800  To be announced
# 16391  3324980             2024
# 16392  3325120      Coming soon
# 16393  3325130      Coming soon
# 16394  3325210  To be announced
# 16396  3325290  To be announced
# 16398  3325350             2025
# 16400  3325590      Coming soon
# 16402  3325620             2024
# 16405  3325730      Coming soon
# 16406  3325780          Q4 2024
# 16407  3325820          Q1 2025
# 16408  3325830    November 2024
# 16409  3325840    December 2024
# 16410  3325870  To be announced
# 16411  3326230  To be announced
# 16412  3326250      Coming soon
# 16413  3326280      Coming soon
# 16414  3326290     January 2025
# 16416  3326460      Coming soon
# 16417  3326600             2025
# 16418  3326610      Coming soon
# 16420  3326830  To be announced
# 16421  3326840    February 2026
# 16422  3326950          Q1 2025
# 16423  3327080  To be announced
# 16424  3327090             2025
# 16426  3327150      Coming soon
# 16430  3327370      Coming soon
# 16431  3327470      Coming soon
# 16433  3327880          Q1 2025
# 16434  3327900      Coming soon
# 16435  3328010          Q1 2025
# 16436  3328020          Q4 2024
# 16437  3328100      Coming soon
# 16439  3328320      Coming soon
# 16440  3328340      Coming soon
# 16441  3328380  To be announced
# 16442  3328390      Coming soon
# 16444  3328530      Coming soon
# 16445  3328700      Coming soon
# 16447  3328810  To be announced
# 16450  3328870    November 2024
# 16451  3328880  To be announced
# 16452  3328940    November 2024
# 16454  3329000      Coming soon
# 16456  3329080          Q4 2024
# 16457  3329220    November 2024
# 16460  3329490          Q4 2025
# 16462  3329570    November 2024
# 16465  3329620       March 2025
# 16470  3330280      Coming soon
# 16471  3330380      Coming soon
# 16472  3330450    November 2024
# 16473  3330470    November 2024
# 16476  3330880      Coming soon
# 16477  3330930      Coming soon
# 16480  3331310    November 2024
# 16482  3331370             2025
# 16483  3331420      Coming soon
# 16484  3331540  To be announced
# 16486  3331610    November 2024
# 16487  3331690      Coming soon
# 16488  3331710      Coming soon
# 16489  3331900      Coming soon
# 16491  3331960      Coming soon
# 16492  3332020      Coming soon
# 16493  3332070     January 2025
# 16494  3332090  To be announced
# 16497  3332670      Coming soon
# 16498  3332700    December 2024
# 16500  3332880      Coming soon
# 16502  3333460          Q1 2025
# 16504  3333790      Coming soon
# 16505  3333900    November 2024
# 16506  3333930    December 2024
# 16507  3333980      Coming soon
# 16508  3334360  To be announced
# 16509  3334510      Coming soon
# 16510  3334610      Coming soon
# 16511  3334630             2025
# 16513  3335650  To be announced
# 16515  3336040      Coming soon
# 16517  3336460          Q1 2025
# 16518  3337050  To be announced
# 16519  3337180      Coming soon
# 16520  3337340      Coming soon
# 16521  3337380             2025
# 16526  3337870    December 2024
# 16527  3337930          Q1 2025
# 16529  3338100    December 2024
# 16530  3338350             2025
# 16531  3338510          Q4 2026
# 16532  3338750          Q1 2025
# 16533  3339450      Coming soon

# %%
english_months = {
    'листоп.': 'Nov'
}
for non_english, english in english_months.items():
    dates_df['release_date'] = dates_df['release_date'].str.replace(non_english, english, regex=False)

def reformat_dates(date):
    try:
        if pd.Series(date).str.match(r'^[A-Z][a-z]{2} \d{1,2}, \d{4}$').iloc[0]:
            dt = pd.to_datetime(date, format='%b %d, %Y')
        elif pd.Series(date).str.match(r'^\d{1,2} [A-Z][a-z]{2}, \d{4}$').iloc[0]:
            dt = pd.to_datetime(date, format='%d %b, %Y')
        else:
            dt = pd.to_datetime("Jan 1, 2025")
        
        if dt > pd.Timestamp("2024-11-12"):
            dt = pd.to_datetime("Jan 1, 2025")

        return dt
    except Exception:
        print("weird date:", date)
        return pd.to_datetime("Jan 1, 2025")

dates_df['release_date'] = dates_df['release_date'].apply(reformat_dates)
# Out:
# weird date: Apr 3, 4444

# %% [markdown]
# Handling NULL prices based on un released games

# %%
price_dates_df = (
    dates_df
    .merge(game_prices_df, on = 'game_id', how = 'left')
)

target_date = pd.to_datetime("Jan 1, 2025")
price_dates_df['current_price'] = np.where(
    (price_dates_df['release_date'] != target_date) & (price_dates_df['current_price'].isna()),
    0,
    np.where(price_dates_df['current_price'].isna(), -1, price_dates_df['current_price'])
)

target_date = pd.to_datetime("Jan 1, 2025")
price_dates_df['initial_price'] = np.where(
    (price_dates_df['release_date'] != target_date) & (price_dates_df['initial_price'].isna()),
    0,
    np.where(price_dates_df['initial_price'].isna(), -1, price_dates_df['initial_price'])
)

# %% [markdown]
# Merging Dates & prices

# %%
game_metrics_df = (
    game_metrics_df
    .merge(price_dates_df, on = 'game_id', how = 'left')
)
game_metrics_df.head()
# Out:
#    game_id                       name  positive_user_score  \
# 0       10             Counter-Strike               236255
# 1       20      Team Fortress Classic                 7330
# 2       30              Day Of Defeat                 6267
# 3       40         Deathmatch Classic                 2553
# 4       50  Half-Life: Opposing Force                22337
#
#    negative_user_score  metacritic_score    ccu  owners_min  owners_max  \
# 0                 6239              88.0  14998    10000000    20000000
# 1                 1093               NaN     62     5000000    10000000
# 2                  672              79.0     98      500000     1000000
# 3                  527               NaN      4     5000000    10000000
# 4                 1116               NaN    101     2000000     5000000
#
#   release_date  current_price  initial_price
# 0   2000-11-01           9.99           9.99
# 1   1999-04-01           4.99           4.99
# 2   2003-05-01           4.99           4.99
# 3   2001-06-01           4.99           4.99
# 4   1999-11-01           4.99           4.99

# %% [markdown]
# Handling duplicates

# %%
developers_df['developer'] = developers_df['developer'].str.lower()
publishers_df['publisher'] = publishers_df['publisher'].str.lower()

# %%
duplicated_metrics = game_metrics_df[game_metrics_df.duplicated(keep=False)]
print(f"duplicated metrics: {duplicated_metrics}\n")
duplicated_game_ids_df = game_metrics_df[game_metrics_df.duplicated(subset=['game_id'], keep=False)]
print(f"duplicated game ids (metrics): {duplicated_game_ids_df}\n")

duplicated_games = games_df[games_df.duplicated(keep=False)]
print(f"duplicated games: {duplicated_games}\n")
duplicated_game_ids_df = games_df[games_df.duplicated(subset=['game_id'], keep=False)]
print(f"duplicated game ids (games): {duplicated_game_ids_df}\n")

duplicated_platforms = platforms_df[platforms_df.duplicated(keep=False)]
print(f"duplicated platforms: {duplicated_platforms}\n")

duplicated_developers = developers_df[developers_df.duplicated(keep=False)]
print(f"duplicated developers: {duplicated_developers}\n")

duplicated_publishers = publishers_df[publishers_df.duplicated(keep=False)]
print(f"duplicated publishers: {duplicated_publishers}\n")

duplicated_genres = genres_df[genres_df.duplicated(keep=False)]
print(f"duplicated genres: {duplicated_genres}\n")
# Out:
# duplicated metrics: Empty DataFrame
# Columns: [game_id, name, positive_user_score, negative_user_score, metacritic_score, ccu, owners_min, owners_max, release_date, current_price, initial_price]
# Index: []
#
# duplicated game ids (metrics): Empty DataFrame
# Columns: [game_id, name, positive_user_score, negative_user_score, metacritic_score, ccu, owners_min, owners_max, release_date, current_price, initial_price]
# Index: []
#
# duplicated games: Empty DataFrame
# Columns: [game_id, name]
# Index: []
#
# duplicated game ids (games): Empty DataFrame
# Columns: [game_id, name]
# Index: []
#
# duplicated platforms: Empty DataFrame
# Columns: [game_id, platform]
# Index: []
#
# duplicated developers:        game_id            developer
# 7752   2342690            tomatoast
# 7753   2342690            tomatoast
# 9040   2532590           bronstudio
# 9041   2532590           bronstudio
# 10805  2775370      disillusion dev
# 10806  2775370      disillusion dev
# 11901  2896220         j.a.p studio
# 11902  2896220         j.a.p studio
# 13626  3068420        imdie studios
# 13627  3068420        imdie studios
# 16167  3245900                   lb
# 16168  3245900                   lb
# 16912  3285780         oedipe games
# 16913  3285780         oedipe games
# 17682  3325870  getcomponent studio
# 17683  3325870  getcomponent studio
#
# duplicated publishers:        game_id         publisher
# 14457  3148790  the lone warrior
# 14458  3148790  the lone warrior
# 16629  3285780      oedipe games
# 16630  3285780      oedipe games
#
# duplicated genres: Empty DataFrame
# Columns: [game_id, genre]
# Index: []

# %%
rows_with_appid = steamworks_df[steamworks_df['appid'] == 2342690]
print(rows_with_appid)
rows_with_appid = steamworks_df[steamworks_df['appid'] == 3148790]
print(rows_with_appid)
# Out:
#         appid          name              developers   publishers  \
# 7611  2342690  Call Of Boba  [Tomatoast, Tomatoast]  [Tomatoast]
#
#       initial_price  final_price  \
# 7611            NaN          NaN
#
#                                             platforms  metacritic  \
# 7611  {'linux': False, 'mac': False, 'windows': True}         NaN
#
#                                                  genres release_date
# 7611  [{'description': 'Action', 'id': '1'}, {'descr...  Coming soon
#          appid       name developers                            publishers  \
# 14791  3148790  Back Door  [Akihire]  [The Lone Warrior, The Lone Warrior]
#
#        initial_price  final_price  \
# 14791            NaN          NaN
#
#                                              platforms  metacritic  \
# 14791  {'linux': False, 'mac': False, 'windows': True}         NaN
#
#                                                   genres  release_date
# 14791  [{'description': 'Adventure', 'id': '25'}, {'d...  Mar 31, 2025

# %%
developers_df = developers_df.drop_duplicates(subset=['game_id', 'developer'])
publishers_df = publishers_df.drop_duplicates(subset=['game_id', 'publisher'])

# %% [markdown]
# Creating Look up and bridge tables

# %%
developers_lookup_df = developers_df[['developer']].drop_duplicates().reset_index(drop=True)
developers_lookup_df['developer_id'] = developers_lookup_df.index+1
game_developers_bridge_df = developers_df.merge(developers_lookup_df, on='developer', how='inner')
game_developers_bridge_df = game_developers_bridge_df[['game_id', 'developer_id']]

publishers_lookup_df = publishers_df[['publisher']].drop_duplicates().reset_index(drop=True)
publishers_lookup_df['publisher_id'] = publishers_lookup_df.index+1
game_publishers_bridge_df = publishers_df.merge(publishers_lookup_df, on='publisher', how='inner')
game_publishers_bridge_df = game_publishers_bridge_df[['game_id', 'publisher_id']]

genres_lookup_df = genres_df[['genre']].drop_duplicates().reset_index(drop=True)
genres_lookup_df['genre_id'] = genres_lookup_df.index+1
game_genres_bridge_df = genres_df.merge(genres_lookup_df, on='genre', how='inner')
game_genres_bridge_df = game_genres_bridge_df[['game_id', 'genre_id']]

platforms_lookup_df = platforms_df[['platform']].drop_duplicates().reset_index(drop=True)
platforms_lookup_df['platform_id'] = platforms_lookup_df.index+1
game_platforms_bridge_df = platforms_df.merge(platforms_lookup_df, on='platform', how='inner')
game_platforms_bridge_df = game_platforms_bridge_df[['game_id', 'platform_id']]

# %%
print(developers_lookup_df.head())
print(game_developers_bridge_df.head())
print(publishers_lookup_df.head())
print(game_publishers_bridge_df.head())
print(genres_lookup_df.head())
print(game_genres_bridge_df.head())
print(platforms_lookup_df .head())
print(game_platforms_bridge_df.head())
# Out:
#                developer  developer_id
# 0                  valve             1
# 1       gearbox software             2
# 2  malfador machinations             3
# 3               techland             4
# 4     popcap games, inc.             5
#    game_id  developer_id
# 0       10             1
# 1       20             1
# 2       30             1
# 3       40             1
# 4       50             2
#              publisher  publisher_id
# 0                valve             1
# 1       strategy first             2
# 2             techland             3
# 3  techland publishing             4
# 4   popcap games, inc.             5
#    game_id  publisher_id
# 0       10             1
# 1       20             1
# 2       30             1
# 3       40             1
# 4       50             1
#           genre  genre_id
# 0        Action         1
# 1  Free To Play         2
# 2      Strategy         3
# 3        Racing         4
# 4        Casual         5
#    game_id  genre_id
# 0       10         1
# 1       20         1
# 2       30         1
# 3       40         1
# 4       50         1
#   platform  platform_id
# 0    linux            1
# 1      mac            2
# 2  windows            3
#    game_id  platform_id
# 0       10            1
# 1       10            2
# 2       10            3
# 3       20            1
# 4       20            2

# %% [markdown]
# Write to CSV

# %%
os.makedirs('../data', exist_ok=True)

game_metrics_df.to_csv('../data/game_metrics.csv', sep =',', encoding = 'utf-8', index = False, header = True)

developers_lookup_df.to_csv('../data/developers_lookup.csv', sep=',', encoding='utf-8', index=False, header=True)
game_developers_bridge_df.to_csv('../data/game_developers_bridge.csv', sep=',', encoding='utf-8', index=False, header=True)

publishers_lookup_df.to_csv('../data/publishers_lookup.csv', sep=',', encoding='utf-8', index=False, header=True)
game_publishers_bridge_df.to_csv('../data/game_publishers_bridge.csv', sep=',', encoding='utf-8', index=False, header=True)

genres_lookup_df.to_csv('../data/genres_lookup.csv', sep=',', encoding='utf-8', index=False, header=True)
game_genres_bridge_df.to_csv('../data/game_genres_bridge.csv', sep=',', encoding='utf-8', index=False, header=True)

platforms_lookup_df.to_csv('../data/platforms_lookup.csv', sep =',', encoding = 'utf-8', index = False, header = True)
game_platforms_bridge_df.to_csv('../data/game_platforms_bridge.csv', sep=',', encoding='utf-8', index=False, header=True)
